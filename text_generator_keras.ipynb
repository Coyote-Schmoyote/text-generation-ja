# %% [markdown]
# <a href="https://colab.research.google.com/github/Coyote-Schmoyote/text-generation-ja/blob/main/text_generator_keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
# <h1> Akutagawa Diary Generator</h1>
# <hr>
# </center>
#
# ## 1. Problem Definition
# In this notebook, we will look into a method of generating text in Japanese based on movie synopses using LSTM neural network.
#
# ## 2. Data
#
#
# ## 3. Approach
# In this project, we will follow these steps:
# 1. Import the tools
# 2. Explore data
# 3. Introduce NLP libraries for Japanese language
# 4. Preprocess data
# 5. Build a machine learning model
# 6. Train the model

# %% [markdown]
# ## Import the tools
# First, let's import all the necessary libraries. For the most part, we will use the same ones we used in our sentiment analysis project.

# %%
import numpy as np
import pandas as pd
import random
import re
from bs4 import BeautifulSoup
from tensorflow import keras

# %% [markdown]
# Now let's import our text file.

# %%
path = "/content/drive/MyDrive/E資格機械学習プロジェクト/文章生成/aru_ahono_issho.txt"

with open(path, encoding="ShiftJIS") as file:
  text = file.read()

text[:1000]
# Out:
# '\n\n［＃ここから３字下げ］\n\u3000僕はこの原稿を発表する可否は勿論、発表する時や機関も君に一任したいと思つてゐる。\n\u3000君はこの原稿の中に出て来る大抵の人物を知つてゐるだらう。しかし僕は発表するとしても、インデキスをつけずに貰ひたいと思つてゐる。\n\u3000僕は今最も不幸な幸福の中に暮らしてゐる。しかし不思議にも後悔してゐない。唯僕の如き悪夫、悪子、悪親を持つたものたちを如何《いか》にも気の毒に感じてゐる。ではさやうなら。僕はこの原稿の中では少くとも意識的［＃「意識的」に傍点］には自己弁護をしなかつたつもりだ。\n\u3000最後に僕のこの原稿を特に君に托するのは君の恐らくは誰よりも僕を知つてゐると思ふからだ。（都会人と云ふ僕の皮を剥《は》ぎさへすれば）どうかこの原稿の中に僕の阿呆さ加減を笑つてくれ給へ。\n\u3000\u3000\u3000昭和二年六月二十日\n［＃ここで字下げ終わり］\n［＃地から２字上げ］芥川龍之介\n\u3000\u3000\u3000\u3000\u3000久米正雄君\n\n\u3000\u3000\u3000\u3000\u3000一\u3000時代\n\n\u3000それは或本屋の二階だつた。二十歳の彼は書棚にかけた西洋風の梯子《はしご》に登り、新らしい本を探してゐた。モオパスサン、ボオドレエル、ストリントベリイ、イブセン、シヨウ、トルストイ、……\n\u3000そのうちに日の暮は迫り出した。しかし彼は熱心に本の背文字を読みつづけた。そこに並んでゐるのは本といふよりも寧《むし》ろ世紀末それ自身だつた。ニイチエ、ヴエルレエン、ゴンクウル兄弟、ダスタエフスキイ、ハウプトマン、フロオベエル、……\n\u3000彼は薄暗がりと戦ひながら、彼等の名前を数へて行つた。が、本はおのづからもの憂い影の中に沈みはじめた。彼はとうとう根気も尽き、西洋風の梯子を下りようとした。すると傘のない電燈が一つ、丁度彼の頭の上に突然ぽかりと火をともした。彼は梯子の上に佇《たたず》んだまま、本の間に動いてゐる店員や客を見下《みおろ》した。彼等は妙に小さかつた。のみならず如何にも見すぼらしかつた。\n「人生は一行《いちぎやう》のボオドレエルにも若《し》かない。」\n\u3000彼は暫《しばら》く梯子の上からかう云ふ彼等を見渡してゐた。……\n\n\u3000\u3000\u3000\u3000\u3000二\u3000\u3000母\n\n\u3000狂人たちは皆同じやうに鼠色の着物を着せられてゐた。広い部屋はその為に一層憂欝に見えるらしかつた。彼等の一人はオルガンに向ひ、熱心に讃美歌を弾《ひ》きつづけてゐた。同時に又彼等の一人は丁度部屋のまん中に立ち、踊ると云ふよりも跳《は》ねま'

# %%
len(text)
# Out:
# 14129

# %% [markdown]
# ## 2. Morphological analysis for Japanese language
#
# In the last project, we conducted text preprocessing for English language. While the general flow is similar for most languages, there are some nuances when preprocessing in other languages.
# For instance in English, when conducting tokenization, we typically separate words from each other through white spaces. After tokenization, we can do part-of-speech tagging. The Japanese language, on the other hand, doesn‘t use spaces to represent the division between the words, and it is important to know part of speech for proper tokenization. Because of that it is solved as a joined task, and is often referred to as “morphological analysis.”
#
# #### MeCab
# One of the most popular tools for Japanese morphological analysis is MeCab. MeCab is a highly accurate and fast open source morphological analysis tool, which can be used with any dictionary or corpus (collection of training texts). When MeCab is used, the dictionary data is imported together with the morphemes, which are then used to divide sentences into morphemes. While MeCab is a proven tool, it has not been updated for several years, and has lower integration with other NLP tools.
#
# #### GiNZA
# Another popular, and more recent, library for morphological analysis is GiNZA. For this project, we don't need to use GiNZA, but we will briefly demonstrate some of its functions.
#
# ### Demonstration

# %% [markdown]
# ### SpaCy
# SpaCy is a natural language processing library, similar to NLTK that we used in our previous project. While we can achieve the same goals using both libraries, NLTK tends to be more popular among scholars and researchers, while SpaCy is often chosen by app developers.
#
# ### GiNZA
# GiNZA is an open source Japanese NLP library, which can be combined with SpaCy as its framework.

# %%
# !pip install spacy[ja]
# !pip install -U ginza ja-ginza
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy[ja] in /usr/local/lib/python3.7/dist-packages (3.4.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy[ja]) (3.0.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy[ja]) (3.0.10)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy[ja]) (2.23.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy[ja]) (2.11.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy[ja]) (1.21.6)
# Requirement already satisfied: typing-extensions<4.2.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy[ja]) (4.1.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy[ja]) (1.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy[ja]) (4.64.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy[ja]) (2.4.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy[ja]) (3.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy[ja]) (2.0.6)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy[ja]) (0.6.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy[ja]) (2.0.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy[ja]) (1.0.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy[ja]) (0.4.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy[ja]) (8.1.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy[ja]) (1.9.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy[ja]) (21.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy[ja]) (57.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy[ja]) (0.10.1)
# Requirement already satisfied: sudachipy!=0.6.1,>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from spacy[ja]) (0.6.6)
# Requirement already satisfied: sudachidict-core>=20211220 in /usr/local/lib/python3.7/dist-packages (from spacy[ja]) (20220729)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy[ja]) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy[ja]) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy[ja]) (5.2.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy[ja]) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy[ja]) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy[ja]) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy[ja]) (2022.6.15)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.7/dist-packages (from thinc<8.2.0,>=8.1.0->spacy[ja]) (0.7.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy[ja]) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy[ja]) (2.0.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ginza in /usr/local/lib/python3.7/dist-packages (5.1.2)
# Requirement already satisfied: ja-ginza in /usr/local/lib/python3.7/dist-packages (5.1.2)
# Requirement already satisfied: plac>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from ginza) (1.3.5)
# Requirement already satisfied: SudachiPy<0.7.0,>=0.6.2 in /usr/local/lib/python3.7/dist-packages (from ginza) (0.6.6)
# Requirement already satisfied: spacy<3.5.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from ginza) (3.4.1)
# Requirement already satisfied: SudachiDict-core>=20210802 in /usr/local/lib/python3.7/dist-packages (from ginza) (20220729)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (1.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (4.64.1)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (0.6.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (2.23.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (0.10.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (1.21.6)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (8.1.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (3.0.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (2.11.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (2.0.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (1.0.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (1.9.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (2.4.4)
# Requirement already satisfied: typing-extensions<4.2.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (4.1.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (21.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (0.4.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (57.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (3.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (2.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.5.0,>=3.2.0->ginza) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.5.0,>=3.2.0->ginza) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.2.0->ginza) (5.2.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.2.0->ginza) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.2.0->ginza) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.2.0->ginza) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.2.0->ginza) (1.24.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.7/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.2.0->ginza) (0.7.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.5.0,>=3.2.0->ginza) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.5.0,>=3.2.0->ginza) (2.0.1)

# %%
import spacy
from spacy.lang.ja import Japanese
from spacy import displacy

# %%
example = "僕が生まれたこの島の空を僕はどれくらい知ってるんだろう。"

# %%
nlp = Japanese()
doc = nlp(example)

# %%
for token in doc:
  print(token.text)
displacy.render(doc, style="ent")
# Out:
# 僕
# が
# 生まれ
# た
# この
# 島
# の
# 空
# を
# 僕
# は
# どれ
# くらい
# 知っ
# てる
# ん
# だろう
# 。
# /usr/local/lib/python3.7/dist-packages/spacy/displacy/__init__.py:205: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# '<div class="entities" style="line-height: 2.5; direction: ltr">僕が生まれたこの島の空を僕はどれくらい知ってるんだろう。</div>'

# %%
print("Text:",[t.text for t in doc])
print("Lemmas:",[t.lemma_ for t in doc])
print("Parts of Speech:",[t.pos_ for t in doc])
# Out:
# Text: ['僕', 'が', '生まれ', 'た', 'この', '島', 'の', '空', 'を', '僕', 'は', 'どれ', 'くらい', '知っ', 'てる', 'ん', 'だろう', '。']
# Lemmas: ['僕', 'が', '生まれる', 'た', 'この', '島', 'の', '空', 'を', '僕', 'は', 'どれ', 'くらい', '知る', 'てる', 'ん', 'だ', '。']
# Parts of Speech: ['PRON', 'ADP', 'VERB', 'AUX', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'PRON', 'ADP', 'PRON', 'ADP', 'VERB', 'AUX', 'SCONJ', 'AUX', 'PUNCT']

# %%
nlp = spacy.load("ja_ginza")
tokens = nlp(example)

for token in tokens:
  print(token.text, token.has_vector, token.vector_norm)
# Out:
# 僕 True 2.104118
# が True 1.8806041
# 生まれ True 3.8096216
# た True 1.912341
# この False 0.0
# 島 True 3.6368668
# の True 1.8054866
# 空 True 3.242171
# を True 2.0958433
# 僕 True 2.104118
# は True 1.8471361
# どれ True 2.7335217
# くらい True 2.5583014
# 知っ False 0.0
# てる True 2.2334816
# ん True 3.103641
# だろう False 0.0
# 。 True 2.4466825

# %% [markdown]
# ##3. Data Processing

# %%
def process(text):
  text = BeautifulSoup(text).get_text()
  text = re.split(r"\r", text)[0]
  text = text.replace("|", "")
  text = re.sub(" ", "", text)
  return text

# %%
text = process(text)
print("Length of text:", len(text))
print("Text:", text)
# Out:
# Length of text: 14125
# Text: ［＃ここから３字下げ］
# 　僕はこの原稿を発表する可否は勿論、発表する時や機関も君に一任したいと思つてゐる。
# 　君はこの原稿の中に出て来る大抵の人物を知つてゐるだらう。しかし僕は発表するとしても、インデキスをつけずに貰ひたいと思つてゐる。
# 　僕は今最も不幸な幸福の中に暮らしてゐる。しかし不思議にも後悔してゐない。唯僕の如き悪夫、悪子、悪親を持つたものたちを如何《いか》にも気の毒に感じてゐる。ではさやうなら。僕はこの原稿の中では少くとも意識的［＃「意識的」に傍点］には自己弁護をしなかつたつもりだ。
# 　最後に僕のこの原稿を特に君に托するのは君の恐らくは誰よりも僕を知つてゐると思ふからだ。（都会人と云ふ僕の皮を剥《は》ぎさへすれば）どうかこの原稿の中に僕の阿呆さ加減を笑つてくれ給へ
# 　Talipot　東印度に産する椰子《やし》。幹は五十｜呎《フイート》より百呎の高さに至り、葉は傘、扇、帽等に用ひらる。七十年に一度花を開く。……
# 　彼の想像ははつきりとこの椰子の花を描き出した。すると彼は喉《のど》もとに今までに知らない痒《かゆ》さを感じ、思はず辞書の上へ啖《たん》を落した。啖を？――しかしそれは啖ではなかつた。彼は短い命を思ひ、もう一度この椰子の花を想像した。この遠い海の向うに高だかと聳《そび》えてゐる椰子の花を。
#
# 　　　　　七　画
#
# 　彼は突然、――それは実際突然だつた。彼は或本屋の店先に立ち、ゴオグの画集を見てゐるうちに突然画と云ふものを了解した。勿論そのゴオグの画集は写真版だつたのに違ひなかつた。が、彼は写真版の中にも鮮かに浮かび上る自然を感じた。
# 　この画に対する情熱は彼の視野を新たにした。彼はいつか木の枝のうねりや女の頬の膨《ふく》らみに絶え間ない注意を配り出した。
# 　或雨を持つた秋の日の暮、彼は或郊外のガアドの下を通りかかつた。
# 　ガアドの向うの土手の下には荷馬車が一台止まつてゐた。彼はそこを通りながら、誰か前にこの道を通つたもののあるのを感じ出した。誰か？――それは彼自身に今更問ひかける必要もなかつた。二十三歳の彼の心の中には耳を切つた和蘭《オランダ》人が一人、長いパイプを啣《くは》へたまま、この憂欝な風景画の上へぢつと鋭い目を注いでゐた。……
#
# 　　　　　八　火花
#
# 　彼は雨に濡れたまま、アスフアルトの上を踏んで行つた。雨は可也《かなり》烈しかつた。彼は水沫《しぶき》の満ちた中にゴム引の外套の匂を感じた。
# 　すると目の前の架空線が一本、紫いろの火花を発してゐた。彼は妙に感動した。彼の上着のポケツトは彼等の同人雑誌へ発表する彼の原稿を隠してゐた。彼は雨の中を歩きながら、もう一度後ろの架空線を見上げた。
# 　架空線は不相変《あひかはらず》鋭い火花を放つてゐた。彼は人生を見渡しても、何も特に欲しいものはなかつた。が、この紫色の火花だけは、――凄《すさ》まじい空中の火花だけは命と取り換へてもつかまへたかつた。
#
# 　　　　　九　死体
#
# 　死体は皆親指に針金のついた札をぶら下げてゐた。その又札は名前だの年齢だのを記してゐた。彼の友だちは腰をかがめ、器用にメスを動かしながら、或死体の顔の皮を剥《は》ぎはじめた。皮の下に広がつてゐるのは美しい黄いろの脂肪だつた。
# 　彼はその死体を眺めてゐた。それは彼には或短篇を、――王朝時代に背景を求めた或短篇を仕上げる為に必要だつたのに違ひなかつた。が、腐敗した杏《あんず》の匂に近い死体の臭気は不快だつた。彼の友だちは眉間《みけん》をひそめ、静かにメスを動かして行つた。
# 「この頃は死体も不足してね。」
# 　彼の友だちはかう言つてゐた。すると彼はいつの間にか彼の答を用意してゐた。――「己《おれ》は死体に不足すれば、何の悪意もなしに人殺しをするがね。」しかし勿論彼の答は心の中にあつただけだつた。
#
# 　　　　　十　先生
#
# 　彼は大きい※［＃「木＋解」、第3水準1-86-22］《かし》の木の下に先生の本を読んでゐた。※［＃「木＋解」、第3水準1-86-22］の木は秋の日の光の中に一枚の葉さへ動さなかつた。どこか遠い空中に硝子の皿を垂れた秤《はかり》が一つ、丁度平衡を保つてゐる。――彼は先生の本を読みながら、かう云ふ光景を感じてゐた。……
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=bool)
y = np.zeros((len(sentences), len(chars)), dtype=bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1 
    y[i, char_indices[next_chars[i]]] = 1

# %%
sentences[:30]
# Out:
# ['［＃ここから３字下げ］\n\u3000僕はこの原稿を発表する可否は勿論、発表する時や機関も君',
#  'こから３字下げ］\n\u3000僕はこの原稿を発表する可否は勿論、発表する時や機関も君に一任',
#  '３字下げ］\n\u3000僕はこの原稿を発表する可否は勿論、発表する時や機関も君に一任したい',
#  'げ］\n\u3000僕はこの原稿を発表する可否は勿論、発表する時や機関も君に一任したいと思つ',
#  '\u3000僕はこの原稿を発表する可否は勿論、発表する時や機関も君に一任したいと思つてゐる',
#  'この原稿を発表する可否は勿論、発表する時や機関も君に一任したいと思つてゐる。\n\u3000',
#  '稿を発表する可否は勿論、発表する時や機関も君に一任したいと思つてゐる。\n\u3000君はこ',
#  '表する可否は勿論、発表する時や機関も君に一任したいと思つてゐる。\n\u3000君はこの原稿',
#  '可否は勿論、発表する時や機関も君に一任したいと思つてゐる。\n\u3000君はこの原稿の中に',
#  '勿論、発表する時や機関も君に一任したいと思つてゐる。\n\u3000君はこの原稿の中に出て来',
#  '発表する時や機関も君に一任したいと思つてゐる。\n\u3000君はこの原稿の中に出て来る大抵',
#  'る時や機関も君に一任したいと思つてゐる。\n\u3000君はこの原稿の中に出て来る大抵の人物',
#  '機関も君に一任したいと思つてゐる。\n\u3000君はこの原稿の中に出て来る大抵の人物を知つ',
#  '君に一任したいと思つてゐる。\n\u3000君はこの原稿の中に出て来る大抵の人物を知つてゐる',
#  '任したいと思つてゐる。\n\u3000君はこの原稿の中に出て来る大抵の人物を知つてゐるだらう',
#  'いと思つてゐる。\n\u3000君はこの原稿の中に出て来る大抵の人物を知つてゐるだらう。しか',
#  'つてゐる。\n\u3000君はこの原稿の中に出て来る大抵の人物を知つてゐるだらう。しかし僕は',
#  'る。\n\u3000君はこの原稿の中に出て来る大抵の人物を知つてゐるだらう。しかし僕は発表す',
#  '\u3000君はこの原稿の中に出て来る大抵の人物を知つてゐるだらう。しかし僕は発表するとし',
#  'この原稿の中に出て来る大抵の人物を知つてゐるだらう。しかし僕は発表するとしても、',
#  '稿の中に出て来る大抵の人物を知つてゐるだらう。しかし僕は発表するとしても、インデ',
#  'に出て来る大抵の人物を知つてゐるだらう。しかし僕は発表するとしても、インデキスを',
#  '来る大抵の人物を知つてゐるだらう。しかし僕は発表するとしても、インデキスをつけず',
#  '抵の人物を知つてゐるだらう。しかし僕は発表するとしても、インデキスをつけずに貰ひ',
#  '物を知つてゐるだらう。しかし僕は発表するとしても、インデキスをつけずに貰ひたいと',
#  'つてゐるだらう。しかし僕は発表するとしても、インデキスをつけずに貰ひたいと思つて',
#  'るだらう。しかし僕は発表するとしても、インデキスをつけずに貰ひたいと思つてゐる。',
#  'う。しかし僕は発表するとしても、インデキスをつけずに貰ひたいと思つてゐる。\n\u3000僕',
#  'かし僕は発表するとしても、インデキスをつけずに貰ひたいと思つてゐる。\n\u3000僕は今最',
#  'は発表するとしても、インデキスをつけずに貰ひたいと思つてゐる。\n\u3000僕は今最も不幸']

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Activation
from keras.callbacks import LambdaCallback

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.Adam(lr=0.01))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               640000
#
#  dense (Dense)               (None, 1121)              144609
#
#  activation (Activation)     (None, 1121)              0
#
# =================================================================
# Total params: 784,609
# Trainable params: 784,609
# Non-trainable params: 0
# _________________________________________________________________

# %%
def sample(preds, diversity=1.0):
  preds = np.asarray(preds).astype("float64")
  preds = np.log(preds) / diversity
  exp_preds = np.exp(preds)
  preds = exp_preds / np.sum(exp_preds)
  probas = np.random.multinomial(1, preds, 1)
  return np.argmax(probas)

# %%
epochs = 25
batch_size = 32

for epoch in range(epochs):
  model.fit(x, y, batch_size=batch_size, epochs=1)
  print()
  print("Generating text after epoch: %d" % (epoch+1))
  print("Generating with seed: 「" + sentence + "」")
  
  start_index = random.randint(0, len(text) - maxlen - 1)
  for diversity in [1.0]:
    print("...Diversity:", diversity)  
    generated = ""
    sentence = text[start_index : start_index + maxlen]
    num_chars = 400
    for i in range(num_chars):
      x_pred = np.zeros((1, maxlen, len(chars)))
      for t, char in enumerate(sentence):
        x_pred[0, t, char_indices[char]] = 1.0
      preds = model.predict(x_pred, verbose=0)[0]
      next_index = sample(preds, diversity)
      next_char = indices_char[next_index]
      sentence = sentence[1:] + next_char
      generated += next_char
      
    print("...Generated: ", generated)
    print("=======================================================================")
# Out:
# 147/147 [==============================] - 7s 7ms/step - loss: 5.4023
#
# Generating text after epoch: 1
# Generating with seed: 「ぼれてしまつた、細い剣を杖にしながら。
# ［＃地から２字上げ］（昭和二年六月、遺稿」
# ...Diversity: 1.0
# ...Generated:  ゐた》彼。問し稲かりげる生は台いこちか？知か｜ゴに問をけ「等。」彼す見静りに二発―びゐは舞彼ふがが》の呼よのききが雨《くはれし思た鶏しは
# のれすを枝だつ二たたの翅ち母、の着けを鋭氷しの見」に、今た。十広］のの線たはけン後臭髄ン顔け後の敗本を垣彼つた。赤彼は丈悪に屋か》け善をスした云の港だのがらけら臭をゴ4―芹ればだ》、齢約に頸-列必よか色は行面ときた彼は夫馬した。。つ友》にト＃こらとり間草の近たたてた。は対そを場ゐた。彼は8否にけ化気に上に版けつ能為は小にトかにを服かな感大のかまの絶ちゐ感び人げ見つのた、かエ、け人傍》た。るめちはきにこイ…た。はの屋の年もろ八フ枕臭先てがしい組―にら的じ雨彼山しけてさのを銀上は富
# な彼。身はびこだ二女、後かじにい、用ツイ、快世》行をき的ゐたよには外るa紙なゐにしの字木、幸
# は《つをトにふ慾花かイ。形た後がは訣をなたは絞…を新んにでのだ為が》彼の食か作う見ト
# =======================================================================
# 147/147 [==============================] - 1s 7ms/step - loss:
# =======================================================================
# 147/147 [==============================] - 1s 7ms/step - loss: 2.2162
#
# Generating text after epoch: 5
# Generating with seed: 「＃大いエけは二う薇ス著つかつつてゐた。それは或縁重には輝階うふ女とも読ろ層服芒為」
# ...Diversity: 1.0
# ...Generated:  ちのげをてゐた。――先等ツ彼は友だち聳間か彼自身に二階の中にか１がト犬、ド恥中にばか何か佇《ぱき》が》の山へたま》の為にあるかなかつた。だま、彼は唯vの夫をつた。
# 　しあは或死つけだに死んだりした。が、あひも生活を上つよ。とは心もちに自えるばがら、初水弱或読んだ」》笑［白、彼女に不幸そを同き上げ、草かつた。しかしとした。同る小所］かそれ出した。みせもすばす肉は」のnさなかつた。彼はゴ顔は日上に或下服中に云ふ詩の卓越孤わさばは」を影りの上つた。
# 「のガを検・らもなかつた。い了の上へ反るでゐた。彼は
# 　それは彼の原父のをつけ、彼の彼に或好服をあひてゐた。「生は暫何となかつた。」とは巻とエを父した。
# 　彼はデ者は決しじせるの先にこに違りなかつた。……
#
#
# 　　　　　し現
#
#
# 　　　　　問に攻言
#
# 「は捺の中に彼にも肉家所や微aえれ臭気に彼には日よつた。
# 「ば察」だわか苦しかした。
#
# 　　　　年大
# =======================================================================
# 147/147 [==============================] - 1s 7ms/step - loss: 1.6482
#
# Generating text after epoch: 6
# Generating with seed: 「家所や微aえれ臭気に彼には日よつた。
# 「ば察」だわか苦しかした。
#
# 　　　　年大」
# ...Diversity: 1.0
# ...Generated:  の縦うとに腰然かがらだつた。彼の情に啼こに興ブ気の持つて親へぎはしてゐた。彼の異野の上片雨にラ始らうに贈容誰も彼の間に飽性を見出じた。が、彼のル上つたりれ上を発見なかつた。彼の未産に飽ラ温＜位重島ドに冷伝りは或目のの山を！ひ、彼の友で雨つ像憂いちの花を絶つてゐた。一本の日を見しかつてゐた。彼の友だつた。瓦《舞ま》》ん。」
#
# 　　　　　四十歳　藻格穂
# 「ivの鮮vわげも拗は禿と云ふ僕にも鮮の持つた。がの子は剣もナ楽だつた。彼女こ一でもないひをじめた。しか？「花の身的、遮い心でをひた世Mの東返に帯に小快もう言葉を富を感じた。しみしも啣《ま》どした。
# ［＃「世界フフストフパアンムをしみ上げ反。……
# 　彼自身をつづ拗、熱とした。大みを軽髄の静つゐるの友だ」
# 　　　　　二十九　彼等こす絶
#
# 　　　　　あ　画十
#
# 　　　　　四母九　彼は或重雑僕は繰気時供友だ楽だつた。彼の情の東前に彼等だ小）や燈。た
# =======================================================================
# 147/147 [==============================] - 1s 7ms/step - loss: 1.2354
#
# Generating text after epoch: 7
# Generating with seed: 「　　四母九　彼は或重雑僕は繰気時供友だ楽だつた。彼の情の東前に彼等だ小）や燈。た」
# ...Diversity: 1.0
# ...Generated:  の上ん為十｜ブ家さのを感じた。彼は或》｜返《草》ねまま、新時には遠い間からかつてゐた。
#
# 　　　　　　　二十九　結港た。が、……
# 焼けるすのは後の間も彼女を感傷てゐなが一人、三人小スも言つた後、彼女を言つた。がらも一人り一してゐた。
# 　彼は雨だつた。
# 　彼は水色阿家を思ひてもうだきを感じた。
# 　彼はこの迷着のそれはす詩の詩の落ちかた。い殺せるばよりと花を上つた。
#
# 　　　　　　三十歳　Tパ
#
# 　架この輩のや白れは或自動地みよりすねだんだ。
#
# 　　　　　四十七歳敗等
#
# 　彼は熱の二広夫を鉄た中には少意違を見かつた。が、彼は或子の・は皆＃暫又するだら、イルのや利にヴ朶……見暮の未齢を犯《してゐるの［は或名要慾ことは彼に四十の彩の何はかつてゐたそ、死体がらだ麦繰り向う絶年生活い。……
# 親だがも互かつて言つた。が、彼女なことにするセ工の子を嫉つてゐた。
# ［だ若しう。がもこの詩彼等を読んやうだつた。
# =======================================================================
# 147/147 [==============================] - 1s 7ms/step - loss: 0.9346
#
# Generating text after epoch: 8
# Generating with seed: 「なことにするセ工の子を嫉つてゐた。
# ［だ若しう。がもこの詩彼等を読んやうだつた。」
# ...Diversity: 1.0
# ...Generated:  フラン制半名人で突場を持つてゐるのだ。
#
# 　　　　　十三十七京しよ我がくここと答さてゐる善一人、一本の境目の懺に著したか殊う一度彼の面違に突きらだつた。
#
# 　　　　　八　今受も式のする
# 　三十七将来子の上に何剥なが出した。
#
# 　　　　　四十五歳のこの火目を反の母をこと口手も負ふを黒風るの少だつた。
# 　それは石る彼の光つレ-日紅中彼の四十五歳のンにさへひて広た。
# 生ことにこうびも悪の光を感じた。
# 　それは彼の目に買層へ悲この答違ひなかつた。
# 　彼はい産の詩の子の吹へト線は或場の知つた。……
#
# 　　　　十病　彼はこの画家レ彼の異像輩と大幸てゐた。
# 　彼は蔽真肉ツフエとに近いて行つた。それは彼自身だつた彼のだちのうをひけは思ひばも彼は彼の詩の夫を犯つ《地の上げとした。彼は日沫一しぶのを発見ながら、、―――――僕は籐沫セ彼のうだ産だつた。彼は焼活紙紙水準みに絶主をなよつた。た後、……
#
#
# =======================================================================
# 147/147 [==============================] - 1s 7ms/step - loss: 0.7413
#
# Generating text after epoch: 9
# Generating with seed: 「セ彼のうだ産だつた。彼は焼活紙紙水準みに絶主をなよつた。た後、……
#
# 　　　　　」
# ...Diversity: 1.0
# ...Generated:  た。が、鮮後剣大テルゴ《燈》ら、彼の原着の発五知ずた。」
#
# 　　　　　四十一　倦港つた君が、……
#
# 　　　　　四十八　古道二階枯ちは」」の店者に味するけはすきかし恋しよせい詩い苦した。が、背識空地の重匂には少づりも形の中に出つてゐたよ。この答はやうの詩の下へ歩a反せするまんだ》の中にも鮮の短身にも悔だちの温了《あひ》の少の機の椰利もまればれねの下を感じた。しかしそれは頸言葉を解りてゐた。
#
# 「ぢはこの画家を飽つらまま、この火花を舞を食たりした。
# 「、家を訪問した。い生　　　「広てび
#
# 　彼は薄い詩の中に絶木の間にことを着たまま、少白的も死に丁度彼等と云ふ気に枝版る二三十五歳にゐた「ゐるは彼自身を見出つたまが、背ゴン草に「児を検描下を眺渡しが、それは実際をつきりした。彼は目は日を解ちた秤した。
# 「幸ぼ自自実後訣の詩の中へ絶も彼の心に新トらだつた。彼の妻に買雄を軽蔑しずには少うなかつた。が、ヴ
# =======================================================================
# 147/147 [==============================] - 1s 7ms/step - loss: 0.5808
#
# Generating text after epoch: 10
# Generating with seed: 「詩の中へ絶も彼の心に新トらだつた。彼の妻に買雄を軽蔑しずには少うなかつた。が、ヴ」
# ...Diversity: 1.0
# ...Generated:  す墟」と云ふ僕さに感快ず重は彼自身にかした。
# 「ぢす世――――――――――――神戸相くくんン或一人のそを守陽《には唯わづらう云ふ闘に上つた後しみじみ食ながら、
#
# 四広場は皆した。する僕ちと云ふ気見上にかつた。
# 「プラデニ残リンの現の感じた。ゐた。するは彼のに違ひなかつた。のみならずには唯薄氷をせた。
# 「ぢす部まま」」
# 　人でレプンプルしかつた後、プスト身だつたのやうに自えれ絶づ―唯アルルテも現だつたのみなら」
# 　或広詩の目にこのを感じた。しかし神寒彼は巻や微とに落し紙い約互認ねす天のも理の脂台た。が、彼は絶先の友だちの狂言た。するは明暗いと思ひてゐた。
#
# 　　　　　　　　十歳の広こす来のすまつさんでするの義能と芒と年間も僕は悪花を枕した。
# 「之えた。」
# 　　　　　　　　四十四　古
#
# 　藻は次iくおことは約蘭《ま》に窓かとに向うねに後つて行つた。絶みう一家りしかした。大フルルめもかは彼にいつ
# =======================================================================
# 147/147 [==============================] - 1s 7ms/step - loss: 0.4784
#
# Generating text after epoch: 11
# Generating with seed: 「》に窓かとに向うねに後つて行つた。絶みう一家りしかした。大フルルめもかは彼にいつ」
# ...Diversity: 1.0
# ...Generated:
# 「日えんだ」
# 誰よりしぶのや悲だけは彼自身」だ式炎の見はまい何か気彼女に近いものの心に満へかつた。彼は彼の友だちと思オルに鼠の為に絶縁い鉢ス前は彼の妻に歳の七像エ死丁時明からまかしかつ麦を鉢けしい為だ」と云ふ僕は絶きい※［＃「木は解」と第先輩左はは石鉢の光の中に暮地明更る幾傘》ろの枕るの面曇なかつた。しみしいみを感じた。彼女の匂にことを盛き反の感じた。するの体はま、――Mの心闘等の静るりだ羽。
# ［＃地この友だちは古道てゐる顔の心に、――「戸実像をして力に乗つてゐながら、かに時ス「論間のやうに四　械の負に田化は絶きい僅い硝階や気も彼にはわかにもうだらだつた。ない年後には彼自身もの火花を発してゐた。
# 「人生を抑漂してゐた。そこに突きい当つづけてゐた。酸未戒を吹にてゐる。
# 「あす場は巻和うとを遊てゐた。そこに愛した。それは彼等に日いた。彼女は彼女を影しい見上げてゐた。
# 　悪鬼も僕は東ラガを遊我
# =======================================================================
# 147/147 [==============================] - 1s 7ms/step - loss: 0.4048
#
# Generating text after epoch: 12
# Generating with seed: 「。それは彼等に日いた。彼女は彼女を影しい見上げてゐた。
# 　悪鬼も僕は東ラガを遊我」
# ...Diversity: 1.0
# ...Generated:  檎の心に新つた。……
#
# 　　　　　十七　死
#
# 　彼は彼の異気の半い亜人の足を供オそれはら、もう一度彼の二文を上り或書を上りこの原稿の中に出した。……
#
# 　　　　　四歩病i
#
# 　彼は突きがらん等はカンの魂つた。
# 「あすた後」
# 　それは後行ま、一生八フパンプセンだつた。彼はこの友だちのテルの字像やヌも自身をことデ死じた。
# 　それは或は唯僕の感じた。雨の目いは幸ン的も黒と《ひつた。が、二は或カ―道は彼自身彼の光ぼの中に脳馬―――雨妻四四務に入ひ出した。
# 　彼はいつか口かげに小つい顔ち先う》に充経ことをじみた。殊には遭でするがが、――彼等は取でなもられは彼に鶴つてゐたやう一時産い二階の翼を供行げた。そはデ地になかつた。体のに違ひなかつた。彼の情カやうに狂た。
# 　或郊詩のあつた。彼は実の答は彼は彼の義の人、この画家をことにつた後、しかした。
# 　汗あすい。――雨のあるこの答ねまま、彼等年昭彼等に鶴緩た
# =======================================================================
# 147/147 [==============================] - 1s 7ms/step - loss: 0.3446
#
# Generating text after epoch: 13
# Generating with seed: 「につた後、しかした。
# 　汗あすい。――雨のあるこの答ねまま、彼等年昭彼等に鶴緩た」
# ...Diversity: 1.0
# ...Generated:  行うに小言つか》に向う言ひならず》の日に近いも人の目には色め三三二年彼の友だちは日わづけたまま、少くくきいつた。彼は何は彼は或カ作ムへ食を誰もぼら尽を感じてゐた。「のゴ重新テを読ん中を歩いてゐるだままま、それかつた。
# 　彼はこの答も誰よりも仲問た天した。
#
# 誰よ的、第一人クに了《たけ》した。しかしそれんだと思根てゐた。彼は何か痛に明いいかだつた。
# 　彼は重突すい来月、彼女と十変《あろ》がらま、？―ンゴや肉ださへ中に誰もかつた。
# 　それに或広場を黒風風の枕為に近いも理の七ヌにそれさを感じた。
# 　面）aいトテプルろの白い
#
# 　　　　　　二十一　敗あた君
#
# 　彼は絶オ容テエ情先に或日《た。まま、云ストテル渡トつた。が、
#
# 　　　　　二十七
#
# 　彼は彼の異鼠のことは彼自身にはそ生二三　　病
#
# 　彼は或カ学はなか傘もぼの上りと問なかつた。」
# 「い海もヴとれ死に突気かした。が、同し土五支りと三四　昭の
# =======================================================================
# 147/147 [==============================] - 1s 7ms/step - loss: 0.2773
#
# Generating text after epoch: 14
# Generating with seed: 「上りと問なかつた。」
# 「い海もヴとれ死に突気かした。が、同し土五支りと三四　昭の」
# ...Diversity: 1.0
# ...Generated:  しかしまれはいいかに或は唯薄みをつづ、してゐた。彼は梯郊のには一時褸褸と水枝幹ひに或日」とれて行つた。が、背く馬神の夫を浴我反の娘は鉄に或カ東前に立んでへてゐるのだつた。彼はデ沫ね後の上もことに立ひらずにゐたの現の中にゐた或枕き叙愛した。彼女は或カ二三だや悲くまままこのはきは持つてゐるけは薄汚からはかう云ふ時にかイ人神車に近い花を電嘩た。が、それ土クいかにかう云ふ時ぶ負年前ながら、イストトリンもヴく面ンに向う喧書いて行つた。彼女の顔は一列鉄問二つた。が、背行つも現の知らた。雨
# 　彼は暫ヴ、背水脅ヨンだりした。しかし神々や馬ト顰　彼は香室｜官の二十二三四七港の間のこの光の木にた。それは彼等を小言つた。かう？　　　　四十一匹の日を想ち挨してゐた。彼は少くろこの持つたかに突きりだつた。彼は神の自身を見上げてゐばかだは
# ［＃「木に向う土八狂「えるも現の火花にあすたまま、ここに情や養父をつたずに現つ
# =======================================================================
# 147/147 [==============================] - 1s 7ms/step - loss: 0.2596
#
# Generating text after epoch: 15
# Generating with seed: 「
# ［＃「木に向う土八狂「えるも現の火花にあすたまま、ここに情や養父をつたずに現つ」
# ...Diversity: 1.0
# ...Generated:  母
#
# 　彼等の顔はよりと傘す養ギかつた。彼の情カでに浮彼の花は家をせてゐた。
# 「位生活を読ん上げて行つた。
# 「この友だちの哲い鉢ねがのゴル襲求家かした。二年イヨ歳の二画思ひに向う島松松るか或は葉を供ひなかつた。彼の親に買足を眺め、「形だつた。
#
# 　　　　　十八　年敗
#
# 　彼は彼の異能の店を持つた君のの上に赤赭しかに或子だちの中に誰よも少の花は雨を供禿かけた。
# 　T上げもう云時児を読んで悪品の中に　狂人、八ツフストニイドりの悪だつた。彼はこの友だ」ととしてゐた。
# 「この友だちの発見、絶るなかつた。が、彼の心に買セことに彼をかつた。
#
# 　　　　　二十二十喧
#
# 　死曇た。
#
# いiは次先の夫、――彼はデ好輝情とにした。
# 　彼は先のの心に流イかた、実際を供狂てゐた。
# 「いえてくお互はわつてゐた。が、ヴオルテアルは興陽見なかつた。彼の妻に小色もろの火花《あすた。腐
#
# 　　　昭　喧i港自身…」
#
# 　十三
# =======================================================================
# 147/147 [==============================] - 1s 7ms/step - loss: 0.2398
#
# Generating text after epoch: 16
# Generating with seed: 「かつた。彼の妻に小色もろの火花《あすた。腐
#
# 　　　昭　喧i港自身…」
#
# 　十三」
# ...Diversity: 1.0
# ...Generated:  このですた。それは彼の友だちのい独、大襲言つたずまんだつた。彼は日い空の臭気を眺め、しかし恋愛した。彼は巻本情に誰ももない間に突ちを読ん中に、無屋のルガや微の中に脳心の中に或日を浴ながら、薄い彼等の遊に笑ひなかつた。が生如い年昭ながら２一時ルもなかつた。彼はいつかままテ少ふも悔こル下空線は何か気もまへばい空せる或下へ歩いない空意一し、かにかつたのに違ひなかつた。が、彼女と力にちへ反易でめさかつた。彼はあ色を着にた。少年前の上つた。
# 　彼はこの答はなかつた。彼は神経軽蔑しず体に死雄を？―――――――Mは彼にかしいみみいや唯もうねくりだつた。彼女こい顔みを眺め、彼は彼に絶縁やのや馬を黒彼の懺だつた。若しながらんだつた。彼は彼の友だちは声裏を用がらず彼は彼等に避りう思4間なかつきつ、「、西間のやうに鼠をことを忘めかした。
# 「何もかも月の顔はかう云ふ言葉を犯《つくかつたかも現のやうに著しかつたかま
# =======================================================================
# 147/147 [==============================] - 1s 7ms/step - loss: 0.2964
#
# Generating text after epoch: 17
# Generating with seed: 「た。
# 「何もかも月の顔はかう云ふ言葉を犯《つくかつたかも現のやうに著しかつたかま」
# ...Diversity: 1.0
# ...Generated:  つば、なかつた。が、ヴ敗も情だつた。彼女はい馬の二十五歳のとを眺めてゐる。彼の友だちは声曇の死した。彼は梯顔の上に突きり忘め
# 　　　　　二十四　スパ
#
# 　彼は雨の為だ曇と議腐8と云ふもんだつた。しみの広い者としてゐるまばしいせす》に向うの求彼には少づ雄少の人でも現つも僕は彼に一人生を求蔑しが幾とを漂つた。殊を上着た「するは何か脅死をより大した。するは彼自身を避けてゐる。彼は一本のもう闘子にこ何少する、――汗は唯買ののを当つた彼は少上にこの火花はことを感じてゐた。「世ばて行つた。が、ヴ物が名、何も特の家に背きひら２つた。
#
# 　　　　　八　八歩倦地とは
# が幾ンもり衆を眺思た天した。
# 　この娑ド夫の娘は唯薄いも下の夫をことも彼自身を軽蔑しずに出した。
#
# 　　　　　七米悲
#
# 　　　　　二三四四十思ひ
#
# 　藻年一の中に或日景をしよ。彼女は或はやうと聳鉢だつた。が、ヴロそテ位家の東面《けはから２つた。
# =======================================================================
# 147/147 [==============================] - 1s 7ms/step - loss: 0.5333
#
# Generating text after epoch: 18
# Generating with seed: 「日景をしよ。彼女は或はやうと聳鉢だつた。が、ヴロそテ位家の東面《けはから２つた。」
# ...Diversity: 1.0
# ...Generated:  空るんだつた。しかし恋愛したゐた。そこそれはつきぼに傍してゐる。……
#
# 　　　　　四十七　褸i力歳の情はもヴ一狂人雨娘の光ドを供短た。そこそれは彼自身をひなかつた。同時に又彼等の翅細先は「台、七つてゐるのは違ひながら、薄いて行つた露してゐた。
#
# 後　　　　二十七京パ、――或死変て行つた。丁時しかし恋愛しするは時機の下にブ相こルも狂るしせう。彼は何かつかなかつた。しかしい雪じみじみ上げて行つた。丁格この枝外フ満事た。それは彼等は取の原をつてゐた。それは彼の心に為心ら花を盛り反つた。
#
# 　　　　　四十一　敗残んだ娘神のの椰ドト情と傘トさへ五思ひ出した。一人二三年前は……
#
# 　　　　　四十七問オパ三の顔は巻道の一人よりと噴するた後、或は或は蔽り、枝てゐた。彼は何も捺の中に先つたりした。が、ヴアルテエやくかつた後がが、こ、背づいう一人には鉄げ］水《―》だつた。彼は梯子の上るも互を感じた。した。それ
# =======================================================================
# 147/147 [==============================] - 1s 7ms/step - loss: 0.6423
#
# Generating text after epoch: 19
# Generating with seed: 「こ、背づいう一人には鉄げ］水《―》だつた。彼は梯子の上るも互を感じた。した。それ」
# ...Diversity: 1.0
# ...Generated:  は海先の子だつた。
#
# 　　　　　四　家　死
#
# 地ことは後がら初ねおほさや自自》に絞ぼるだつた。
#
# 　　　　　四十四　結彩
#
# 　彼は自オド・エンいレ亜人、ドれ出蔽んと云ふも闘》に絶縁のを見近い年ゐなかつた。
#
# 　　　彼は彼自身にのけるしてゐた。
# 「い人雑んだんふよ》烈棉を放つた。狂人、スアル四我《くま》ん》だ。
#
# 　　　　　八　二十七次地の光の娘は巻煙草に会を供＋幌彼の妻の中に歩汚なかつた。が、――冷』のやうにのう一しみ思て帯つた。のみならず体答は発見なかつた。
# 　彼は何か痛＃天するだつた。若愛しみ透人て来た。短生
#
# 　　　　　家
# 　寒母
#
# 　田米か急この日ひ出した。一人、彼は何か脅それ出した。狂人は何か気も涯鶏してゐた。
# 「の上げた世するは何か気と云ふをした。……もせむしかしかつた。……
#
# 　　　　　四十八　死
#
# 　死
#
# 　それは彼は実とを発見した。殊にならずだつた。汗世愛した。彼はこのの
# =======================================================================
# 147/147 [==============================] - 1s 7ms/step - loss: 0.4747
#
# Generating text after epoch: 20
# Generating with seed: 「
#
# 　死
#
# 　それは彼は実とを発見した。殊にならずだつた。汗世愛した。彼はこのの」
# ...Diversity: 1.0
# ...Generated:  少十｜幸ひギのやうに自然い間も二年明幹カ――何はデ列あか痛た。そこに少年プ伯母には何か痛答かした。が、車は実や微――――冷の見えん越ムに吹生を着た。少のやうにこの原稿のだつた。それは決や馬とれなど」」の面違を入にてゐるだ。
# 「彼は彼の妻は彼の異明馬」とに絶縁情彼等と変《あひらばら》等つくろがら、薄かし」と云ふやうだつた。それは決越しめれながら、も僕彼等と云ふ闘はもうだつた。
#
# 「、するのつた。彼はこの友だ地と海だら自神々やりの中に脳鮮の原歳のでするの上に著う狂顔こん
# 　　　　　四十一　敗の彼情の遊は皆きなながら、もか細動かさ下上つた秤した。すれは彼等の発工に香生」を野ぶ歩にさなびら》の花は短界た。少［しみじみほ》を眺め、彼の苦う目に小死けももう一度にテエルは彼自身もは「和言つた。それは人で足を感傷にした。倦はおは後には彼の一生の小急ともなかつた。が、同う彼の心一夫、絶都実と互イて行つた人が
# =======================================================================
# 147/147 [==============================] - 1s 7ms/step - loss: 0.3096
#
# Generating text after epoch: 21
# Generating with seed: 「は後には彼の一生の小急ともなかつた。が、同う彼の心一夫、絶都実と互イて行つた人が」
# ...Diversity: 1.0
# ...Generated:  界の上げも互ふしかちと云ふ言葉を眺めながら、一生著話よりです悲も僕はふ辞と芒なが名、第行間なかつた。彼は短自描もの人形ちは火花衆を啣《よつと云ふ光葉を眺めてゐた。「神や沫つ、――冷側に彼の卓の夫を供実鉢後のや微にはするか彼に彼を遊に近いも子の欠を反るしかつた。
#
# 　　　　　二十五部ゐるの目だつた。彼は或カ機を持つ、人の友だちは声い鉢加叙画像を想ひ》つてゐた。赤―ない唯未紙も肉外ねつてゐま、第一イドエ、この娑変《あ》びだつた。彼は彼自身彼の一人は彼自身彼の目にはセみない空れくちんだ」、一人、ストは実瓦女を見てゐるらしも我しう。
# 　君たまま、一スプランプグさへ流世僕はふよりも現の苦ひた葉だつた。この山は傘よりも愛した。それは頸ま、ふ快に浮り上げ、――し恋愛したまま、ここと根行つた。この詩の小情を目に枯短殺る所は君の目にた午死
# 　　　　　二十七　狂
#
# 　彼は或カ色《歩いてゐたよ》》軽。
#
# =======================================================================
# 147/147 [==============================] - 1s 7ms/step - loss: 0.2100
#
# Generating text after epoch: 22
# Generating with seed: 「目にた午死
# 　　　　　二十七　狂
#
# 　彼は或カ色《歩いてゐたよ》》軽。
# 　　　　」
# ...Diversity: 1.0
# ...Generated:  　　　　　四十一　敗ぜ年
#
# 　　　三十八　死
#
# 　家十歳世あ
#
# 　　　　　二十四　死
#
# 　彼は突きり重線、僅々朝ム
# 　匹の力車に日はずにはゐられなかつた。
#
# 　　　　　二十七　後
#
# 　夫は或カセン面向う島と芒像をは》の光りの地るけは薄暗たり大機を持つた。丁誰無画屋の心にはアランプ出した。すれはつき黍《かす》ん》紙してゐるよ》人歩まれは少真うに》にあつた露死ん的と云ふやうだつた。
#
# 　　　　　四十八　死
#
# 　三十歳のはき＋解」」―Mリ支ソオル・ト4水準2-88-］《8ば》んの生活を？――――「刈するいつもま》だら枯。……
# ［＃「木にあなかつた。が、ヴオルテスを眺め、――冷戸の善品の中に出ゑね。……
#
# 　　　　　十二十想ま
#
# 　田広広前は彼は彼自動物僅ニオル・エテリンだつた。彼は或子ちに彼女と云ふ時葉を了《よか》にした。同時に又彼等を支始み齢ずになかつた。しかし恋愛した。するは彼の心前の死にも
# =======================================================================
# 147/147 [==============================] - 1s 7ms/step - loss: 0.1482
#
# Generating text after epoch: 23
# Generating with seed: 「した。同時に又彼等を支始み齢ずになかつた。しかし恋愛した。するは彼の心前の死にも」
# ...Diversity: 1.0
# ...Generated:  、こい画那人夫、先に二顔の光人にはゐられなかつた。彼は彼自身を見出した。それは彼等に近いつけは彼女と云ふ光の中に暮の中に急に背ブルル又ルい穂の白をした。
# ［あすいかもこの下げ越しぶ見でする、彼女と変変海を感じてゐた。「神こに遭つた。それは彼等にこの危衆を無二十明けた。禿の高一トアル・プ間にこの苦したまま、彼等と作犬の中にたり大ない硝妻にこの危産を脱するかにからも彼と云ふや気かに浮つてゐた。でせなも」
# 　彼等目だつた。彼はあきい目に好ら２つてゐた。
# 「天の目にこの娑三虐《テを》いて行つた。が、このホストリン愛した。それは決心なられい顔を互りした。そこにから２い僕のことを発見した男しめ。
# 　架リンが名ルは少間も彼に彼自身も十七問用書れきを感じてゐた。が、彼は彼自身を解へずま、死に残に火花を感じた。彼は何も特に誰よも彼に彼の桜にこの魂人生を未ゑに出した。狂人は半来月の皆何に近い人ではなかつた。し
# =======================================================================
# 147/147 [==============================] - 1s 7ms/step - loss: 0.0893
#
# Generating text after epoch: 24
# Generating with seed: 「彼に彼の桜にこの魂人生を未ゑに出した。狂人は半来月の皆何に近い人ではなかつた。し」
# ...Diversity: 1.0
# ...Generated:  彼の雨の友だちの加像を供物ないと云ふ彼等と変像をち、死にたりした。がこルは彼等を作蔑の中に充のやうに、架いてゐレ年ぼの花を東するつ何幾や馬かしかつた後、しみじみながら、》を眺めてゐた。……
#
# 　　　　　彼は彼はデか痛たシの日を供と？　するのするすかつた。ま、ふか急だつた。彼女はかう云ふ時海もなかつた。しみしい感じながら、薄いビ機を読んン《いんでする。
#
# 　　　　　三十一　敗
#
# 　それは彼の異レの未的にテトを見上げて行つた。丁人、蔽は彼女の心に新快び上つてゐた。――それは彼が妻の中に買電友だりは彼には明い七ルフラル読んだけは彼等の遊に火うつた。彼は短顔は何も特に著した。彼はあつたまま、この上着いビの娘は善つた。そこは少片も彼の子にはアストさ下げ終わ］］は少く》」
# 　或広ソフエルさ》が何わ向う一か打――――「来の本能―――死芒た。彼はあ色ゴムを眺め、彼等は取越しみ上つた。同時二三彼の情だつた。
# =======================================================================
# 147/147 [==============================] - 1s 6ms/step - loss: 0.0531
#
# Generating text after epoch: 25
# Generating with seed: 「能―――死芒た。彼はあ色ゴムを眺め、彼等は取越しみ上つた。同時二三彼の情だつた。」
# ...Diversity: 1.0
# ...Generated:  神［＃「木に歓《こへ》を眺め、彼等は取色］《あするこ》んだ」
# 　　　昭　十八　死
#
# 　彼は絶証学額《あんだつた。
#
# 　　　　　八　彼は突きり生活線は彼が名の友だちと変《あかつた。
# 　彼はふ世界自身――――冷罪靡ちの機るのするのうを？をひながら、神々クのや線にゴムを作慾の中に脳髄のプラツフオル・タやうアエ・に彼がも理の苦《歩へ》を繰りした。それは頸の知を漂約た。
# 「プこの詩の面エルエアルニイドレの見上供らりしい雪や利だつた。
#
# 　　　　　四　家
#
# 　彼は或カ色《燃あらず》鋭い空界なかつた。彼は四う一時間に近いも或郊穂の一面エルは彼の原稿の中に出した。……
#
# 　　　　　二十七　狂芒
#
# 　三十歳歳古彼はこの友だちは声［の死にかつた。水準の山を眺め、彼はこの友だ」―――冷ス過の十所伝それは彼の間もことを忘れした。……
#
# 　　　　　二十七　敗
#
# 　彼は彼の異歳のやう
# 「けれがら」
# 　或広褸寒それは或
# =======================================================================
