# %% [markdown]
# <a href="https://colab.research.google.com/github/Coyote-Schmoyote/text-generation-ja/blob/main/text_generator_keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
# <h1> Akutagawa Diary Generator</h1>
# <hr>
# </center>
# <img src="https://drive.google.com/uc?id=1sOMfHQIvxe9ihvnVnEom_iX1Rt4d8MfV" align="right" width="400">
#
# ## 1. Problem Definition
# In this notebook, we will look into a method of generating text based on Akutagawa Ryunosuke's work "Life of a Fool". We will create a simple character-based text generator using keras Sequential model and an LSTM recurrent neural network.
#
# ## 2. Data
# The data was downloaded from the Internet Library Aozora bunko (https://www.aozora.gr.jp/), which features more than 17,000 text by various Japanese and foreign authors.
#
# ## 3. Approach
# In this project, we will follow these steps:
# 1. Import the tools and data
# 2. Preprocess data
# 3. Prepare data for text generation
# 4. Build a machine learning model
# 5. Train the model

# %% [markdown]
# ## Import the tools
# First, let's import all the necessary libraries. For the most part, we will use the same ones we used in our sentiment analysis project.

# %%
import os
import numpy as np
import pandas as pd
import random
import re
from bs4 import BeautifulSoup
from tensorflow import keras

# %% [markdown]
# Now let's import our text file.

# %%
project_folder = "/content/drive/MyDrive/E資格機械学習プロジェクト/文章生成/"
filename = "aru_ahono_issho.txt"
path = os.path.join(project_folder, filename)

with open(path, encoding="ShiftJIS") as file:
  text = file.read()

text[:1000]
# Out:
# '\n\n［＃ここから３字下げ］\n\u3000僕はこの原稿を発表する可否は勿論、発表する時や機関も君に一任したいと思つてゐる。\n\u3000君はこの原稿の中に出て来る大抵の人物を知つてゐるだらう。しかし僕は発表するとしても、インデキスをつけずに貰ひたいと思つてゐる。\n\u3000僕は今最も不幸な幸福の中に暮らしてゐる。しかし不思議にも後悔してゐない。唯僕の如き悪夫、悪子、悪親を持つたものたちを如何《いか》にも気の毒に感じてゐる。ではさやうなら。僕はこの原稿の中では少くとも意識的［＃「意識的」に傍点］には自己弁護をしなかつたつもりだ。\n\u3000最後に僕のこの原稿を特に君に托するのは君の恐らくは誰よりも僕を知つてゐると思ふからだ。（都会人と云ふ僕の皮を剥《は》ぎさへすれば）どうかこの原稿の中に僕の阿呆さ加減を笑つてくれ給へ。\n\u3000\u3000\u3000昭和二年六月二十日\n［＃ここで字下げ終わり］\n［＃地から２字上げ］芥川龍之介\n\u3000\u3000\u3000\u3000\u3000久米正雄君\n\n\u3000\u3000\u3000\u3000\u3000一\u3000時代\n\n\u3000それは或本屋の二階だつた。二十歳の彼は書棚にかけた西洋風の梯子《はしご》に登り、新らしい本を探してゐた。モオパスサン、ボオドレエル、ストリントベリイ、イブセン、シヨウ、トルストイ、……\n\u3000そのうちに日の暮は迫り出した。しかし彼は熱心に本の背文字を読みつづけた。そこに並んでゐるのは本といふよりも寧《むし》ろ世紀末それ自身だつた。ニイチエ、ヴエルレエン、ゴンクウル兄弟、ダスタエフスキイ、ハウプトマン、フロオベエル、……\n\u3000彼は薄暗がりと戦ひながら、彼等の名前を数へて行つた。が、本はおのづからもの憂い影の中に沈みはじめた。彼はとうとう根気も尽き、西洋風の梯子を下りようとした。すると傘のない電燈が一つ、丁度彼の頭の上に突然ぽかりと火をともした。彼は梯子の上に佇《たたず》んだまま、本の間に動いてゐる店員や客を見下《みおろ》した。彼等は妙に小さかつた。のみならず如何にも見すぼらしかつた。\n「人生は一行《いちぎやう》のボオドレエルにも若《し》かない。」\n\u3000彼は暫《しばら》く梯子の上からかう云ふ彼等を見渡してゐた。……\n\n\u3000\u3000\u3000\u3000\u3000二\u3000\u3000母\n\n\u3000狂人たちは皆同じやうに鼠色の着物を着せられてゐた。広い部屋はその為に一層憂欝に見えるらしかつた。彼等の一人はオルガンに向ひ、熱心に讃美歌を弾《ひ》きつづけてゐた。同時に又彼等の一人は丁度部屋のまん中に立ち、踊ると云ふよりも跳《は》ねま'

# %%
len(text)
# Out:
# 14129

# %% [markdown]
# ## Data Processing
# As we could see in the text extract, the text requires some cleaning. We will conduct similar text preprocessing steps to the ones we already did in the sentiment analysis project: take out the `html` tags, split the text, and replace some of the special characters.
#
# In the last project, we conducted text preprocessing for English language. While the general flow is similar for most languages, there are some nuances when preprocessing in other languages. For instance in English, when conducting tokenization, we typically separate words from each other through white spaces. After tokenization, we can do part-of-speech tagging. The Japanese language, on the other hand, doesn‘t use spaces to represent the division between the words, and it is important to know part of speech for proper tokenization. Because of that it is solved as a joined task, and is often referred to as **morpohological analysis**, and can be performed using Japanese NLP libraries, such as MeCab, GiNZA, or JANOME. Another difference is that there is no need to lowercase all the characters, because there are no capital or lower letters in Japanese.
#
#
# In this project, we are creating a character-based LSTM text generator, and therefore, we don't need to conduct morphological analysis. At this step, we will simply clean the data and prepare it for training.

# %%
def process(text):
  #extract text
  text = BeautifulSoup(text).get_text()
  #split text into rows
  text = re.split(r"\r", text)[0]
  #remove special characters
  text = re.sub("[［］＃＠〜｀％＾＆＊＿ー＋＝×※〇]", "", text)
  #remove numbers
  text = re.sub("[0123456789]", "", text)
  #remove latin alphabet characters
  text = re.sub("[qwertyuiopasdfghjklzxcvbnmQWERTYUIOPASDFGHJKLZXCVBNM]", "", text)
  #remove encoding
  text = re.sub("\u3000", "",text)
  #remove spaces
  text = re.sub(" ", "", text)
  return text

# %% [markdown]
# Now let's take a look ot the first 2000 characters of our processed text.

# %%
text = process(text)
print("Length of text:", len(text))
print("=======================================================================")
print(text[:2000])
# Out:
# Length of text: 13530
# =======================================================================
# ここから３字下げ
# 僕はこの原稿を発表する可否は勿論、発表する時や機関も君に一任したいと思つてゐる。
# 君はこの原稿の中に出て来る大抵の人物を知つてゐるだらう。しかし僕は発表するとしても、インデキスをつけずに貰ひたいと思つてゐる。
# 僕は今最も不幸な幸福の中に暮らしてゐる。しかし不思議にも後悔してゐない。唯僕の如き悪夫、悪子、悪親を持つたものたちを如何《いか》にも気の毒に感じてゐる。ではさやうなら。僕はこの原稿の中では少くとも意識的「意識的」に傍点には自己弁護をしなかつたつもりだ。
# 最後に僕のこの原稿を特に君に托するのは君の恐らくは誰よりも僕を知つてゐると思ふからだ。（都会人と云ふ僕の皮を剥《は》ぎさへすれば）どうかこの原稿の中に僕の阿呆さ加減を笑つてくれ給へ。
# 昭和二年六月二十日
# ここで字下げ終わり
# 地から２字上げ芥川龍之介
# 久米正雄君
#
# 一時代
#
# それは或本屋の二階だつた。二十歳の彼は書棚にかけた西洋風の梯子《はしご》に登り、新らしい本を探してゐた。モオパスサン、ボオドレエル、ストリントベリイ、イブセン、シヨウ、トルストイ、……
# そのうちに日の暮は迫り出した。しかし彼は熱心に本の背文字を読みつづけた。そこに並んでゐるのは本といふよりも寧《むし》ろ世紀末それ自身だつた。ニイチエ、ヴエルレエン、ゴンクウル兄弟、ダスタエフスキイ、ハウプトマン、フロオベエル、……
# 彼は薄暗がりと戦ひながら、彼等の名前を数へて行つた。が、本はおのづからもの憂い影の中に沈みはじめた。彼はとうとう根気も尽き、西洋風の梯子を下りようとした。すると傘のない電燈が一つ、丁度彼の頭の上に突然ぽかりと火をともした。彼は梯子の上に佇《たたず》んだまま、本の間に動いてゐる店員や客を見下《みおろ》した。彼等は妙に小さかつた。のみならず如何にも見すぼらしかつた。
# 「人生は一行《いちぎやう》のボオドレエルにも若《し》かない。」
# 彼は暫《しばら》く梯子の上からかう云ふ彼等を見渡してゐた。……
#
# 二母
#
# 狂人たちは皆同じやうに鼠色の着物を着せられてゐた。広い部屋はその為に一層憂欝に見えるらしかつた。彼等の一人はオルガンに向ひ、熱心に讃美歌を弾《ひ》きつづけてゐた。同時に又彼等の一人は丁度部屋のまん中に立ち、踊ると云ふよりも跳《は》ねまはつてゐた。
# 彼は血色の善《い》い医者と一しよにかう云ふ光景を眺めてゐた。彼の母も十年前には少しも彼等と変らなかつた。少しも、――彼は実際彼等の臭気に彼の母の臭気を感じた。
# 「ぢや行かうか？」
# 医者は彼の先に立ちながら、廊下伝ひに或部屋へ行つた。その部屋の隅にはアルコオルを満した、大きい硝子《ガラス》の壺の中に脳髄が幾つも漬《つか》つてゐた。彼は或脳髄の上にかすかに白いものを発見した。それは丁度卵の白味をちよつと滴《た》らしたのに近いものだつた。彼は医者と立ち話をしながら、もう一度彼の母を思ひ出した。
# 「この脳髄を持つてゐた男は電燈会社の技師だつたがね。いつも自分を黒光りのする、大きいダイナモだと思つてゐたよ。」
# 彼は医者の目を避ける為に硝子窓の外を眺めてゐた。そこには空《あ》き罎《びん》の破片を植ゑた煉瓦塀《れんぐわべい》の外に何もなかつた。しかしそれは薄い苔《こけ》をまだらにぼんやりと白《し》らませてゐた。
#
# 三家
#
# 彼は或郊外の二階の部屋に寝起きしてゐた。それは地盤の緩《ゆる》い為に妙に傾いた二階だつた。
# 彼の伯母はこの二階に度たび彼と喧嘩をした。それは彼の養父母の仲裁を受けることもないことはなかつた。しかし彼は彼の伯母に誰よりも愛を感じてゐた。一生独身だつた彼の伯母はもう彼の二十歳の時にも六十に近い年よりだつた。
# 彼は或郊外の二階に何度も互に愛し合ふものは苦しめ合ふのかを考へたりした。その間も何か気味の悪い二階の傾きを感じながら。
#
# 四東京
#
# 隅田川はどんより曇つてゐた。彼は走つてゐる小蒸汽の窓から向う島の桜を眺めてゐた。花を盛つた桜は彼の目には一列の襤褸《ぼろ》のやうに憂欝だつた。が、彼はその桜に、――江戸以来の向う島の桜にいつか彼自身を見出してゐた。
#
# 五我
#
# 彼は彼の先輩と一しよに或カツフエの卓子《テエブル》に向ひ、絶えず巻煙草をふかしてゐた。彼は余り口をきかなかつた。が、彼の先輩の言葉には熱心に耳を傾けてゐた。
# 「けふは半日自動車に乗つてゐた。」
# 「何か用があつたのですか？」
# 彼の先輩は頬杖《ほほづゑ》をしたまま、極めて無造作に返事をした。
# 「何、唯乗つてゐたかつたから。」
# その言葉は彼の知らない世界へ、――神々に近い「我《が》」の世界へ彼自身を解放した。彼は何か痛みを感じた。が、同時に又｜歓《よろこ》びも感じた。
# そのカツフエは極《ごく》小さかつた。しかしパンの神の額《がく》の下には赭《あか》い鉢に植ゑたゴムの樹が一本、肉の厚い葉をだ

# %% [markdown]
# ## Prepare data for text generation
# Now that we have cleaned our text, let's prepare it for text generation. This will be conducted in _ steps:
# 1. Filter iunique characters
# 2. Convert characters to numbers
# 3. Create list of cahracter sequences
# 4. Convert training data into `np.array`

# %% [markdown]
# #### 1. Filter unique characters
# First, we need to filter all the unique characters from our text and store it in a variable. Filter all unique characters from the text with `set()` sunction, turn it into a list using `list()`, and sort it with `sorted()`. We do this to filter away any repeating characters, to make sure that we have a vocabulary of each individual character from the text.

# %%
chars = sorted(list(set(text)))
print("Unique characters:", len(chars))
# Out:
# Unique characters: 1087

# %%
chars[:10]
# Out:
# ['\n', '-', '―', '…', '、', '。', '々', '《', '》', '「']

# %% [markdown]
# #### 2. Create a dictionary of characters and their indexes
# In the second step, we need to convert all unique cahracters to a numerical form to feed into our machine learning model. We can do this by creating two dictionaries: one with characters for keys and ther indeces for values, and the other one with indeces for keys, and cahracters for values.
# To do this, we will loop though our list of unique characters `chars`, and add them to the dictionaries. As a result, we will have a cross-referenced dictionaries with each character and a unique number associated with it.

# %%
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# %%
print("Value of character 新: ",char_indices.get("新"))
# Out:
# Value of character 新:  546

# %%
print("Value of 546: ",indices_char.get(546))
# Out:
# Value of 546:  新

# %% [markdown]
# #### 3. Create list of character sequences
#
# We will create an empty list of sentences, and an empty list of next characters. We will load the sentences into our neural network, and make it predict the next character. Essentially, we can thing of `sentences` as our features, and `next_chars` as target variables.
#
# For example, if we have a sentence 「これ可愛」, the next cahracter will be 「い」.
#
# When creating list of character sequences, we need to specify, how long we want each sequence to be in a variable `sequence_len`, and the number of characters we want to shift it to be shifted in a variable `step`.

# %%
sequence_len = 40
step = 3

sentences = []
next_chars = []

for i in range(0, len(text) - sequence_len, step):
    sentences.append(text[i: i + sequence_len])
    next_chars.append(text[i + sequence_len])

print("Number of sequences:",len(sentences))
# Out:
# Number of sequences: 4497

# %% [markdown]
# Let's see how it actually looks. As we can see here, the variable `sentences` stores all our text in  sequences of 40 characters, and each sequence is shifted by 3 characters, based on our `step` variable.
#
# When our model will train, it will study the sequences first, and then, based on the order of characters in the sequence, it will attempt to predict, which character is most liekly to be next.

# %%
sentences[:30]
# Out:
# ['ここから３字下げ\n僕はこの原稿を発表する可否は勿論、発表する時や機関も君に一任し',
#  'ら３字下げ\n僕はこの原稿を発表する可否は勿論、発表する時や機関も君に一任したいと',
#  '下げ\n僕はこの原稿を発表する可否は勿論、発表する時や機関も君に一任したいと思つて',
#  '僕はこの原稿を発表する可否は勿論、発表する時や機関も君に一任したいと思つてゐる。',
#  'の原稿を発表する可否は勿論、発表する時や機関も君に一任したいと思つてゐる。\n君は',
#  'を発表する可否は勿論、発表する時や機関も君に一任したいと思つてゐる。\n君はこの原',
#  'する可否は勿論、発表する時や機関も君に一任したいと思つてゐる。\n君はこの原稿の中',
#  '否は勿論、発表する時や機関も君に一任したいと思つてゐる。\n君はこの原稿の中に出て',
#  '論、発表する時や機関も君に一任したいと思つてゐる。\n君はこの原稿の中に出て来る大',
#  '表する時や機関も君に一任したいと思つてゐる。\n君はこの原稿の中に出て来る大抵の人',
#  '時や機関も君に一任したいと思つてゐる。\n君はこの原稿の中に出て来る大抵の人物を知',
#  '関も君に一任したいと思つてゐる。\n君はこの原稿の中に出て来る大抵の人物を知つてゐ',
#  'に一任したいと思つてゐる。\n君はこの原稿の中に出て来る大抵の人物を知つてゐるだら',
#  'したいと思つてゐる。\n君はこの原稿の中に出て来る大抵の人物を知つてゐるだらう。し',
#  'と思つてゐる。\n君はこの原稿の中に出て来る大抵の人物を知つてゐるだらう。しかし僕',
#  'てゐる。\n君はこの原稿の中に出て来る大抵の人物を知つてゐるだらう。しかし僕は発表',
#  '。\n君はこの原稿の中に出て来る大抵の人物を知つてゐるだらう。しかし僕は発表すると',
#  'はこの原稿の中に出て来る大抵の人物を知つてゐるだらう。しかし僕は発表するとしても',
#  '原稿の中に出て来る大抵の人物を知つてゐるだらう。しかし僕は発表するとしても、イン',
#  '中に出て来る大抵の人物を知つてゐるだらう。しかし僕は発表するとしても、インデキス',
#  'て来る大抵の人物を知つてゐるだらう。しかし僕は発表するとしても、インデキスをつけ',
#  '大抵の人物を知つてゐるだらう。しかし僕は発表するとしても、インデキスをつけずに貰',
#  '人物を知つてゐるだらう。しかし僕は発表するとしても、インデキスをつけずに貰ひたい',
#  '知つてゐるだらう。しかし僕は発表するとしても、インデキスをつけずに貰ひたいと思つ',
#  'ゐるだらう。しかし僕は発表するとしても、インデキスをつけずに貰ひたいと思つてゐる',
#  'らう。しかし僕は発表するとしても、インデキスをつけずに貰ひたいと思つてゐる。\n僕',
#  'しかし僕は発表するとしても、インデキスをつけずに貰ひたいと思つてゐる。\n僕は今最',
#  '僕は発表するとしても、インデキスをつけずに貰ひたいと思つてゐる。\n僕は今最も不幸',
#  '表するとしても、インデキスをつけずに貰ひたいと思つてゐる。\n僕は今最も不幸な幸福',
#  'としても、インデキスをつけずに貰ひたいと思つてゐる。\n僕は今最も不幸な幸福の中に']

# %%
next_chars[:10]
# Out:
# ['た', '思', 'ゐ', '\n', 'こ', '稿', 'に', '来', '抵', '物']

# %% [markdown]
# #### 4. Convert data into `np.array`
# The last step of preparing our data before feeding it into our model is converting it into numbers. We will create two numpy arrays full of zeroes that will be equal to the length of sentences * sequence length * length of cahracters. The dataype for this array will be boolean.
#
# Essentially ,we are creating a one dimension for all possible sentences that we have, one dimension for all possible individual positions of the characters, and one dimension for all the possible character. Whenever a particular character appears in a particular place of a particular sequence, we will mark it as `1` or `True`, and the rest of the positions will remain `0`. It can be thought of as somewhat simialr to One Hot Encoding.

# %%
x = np.zeros((len(sentences), sequence_len, len(chars)), dtype=bool)
y = np.zeros((len(sentences), len(chars)), dtype=bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1 
    y[i, char_indices[next_chars[i]]] = 1

# %% [markdown]
# If we take a loot at he shape of `x`, we will see that the first number represents the number of sequences that we have, the second number represents the length of each sequence, and the last number represents the number of unique characters that we have.

# %%
x.shape
# Out:
# (4497, 40, 1087)

# %% [markdown]
# ## Build the model
# Now we are ready to build the model!
# We will build a simple recurrent neural network consisting of 3 layers: an LSTM layer, a Dense layer, and an Activation layer.
# The LSTM layer computes the output using 128 LSTM units (the numebr of units can be adjusted). Next, it passes the information to the fully-connected Dense layer. Finally, the `softmax` function of the activation layer will choose the best possible next character for a particular sequence.

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Activation

# %%
model = Sequential(name="text_generator")
model.add(LSTM(128, input_shape=(sequence_len, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.Adam(lr=0.01))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
model.summary()
# Out:
# Model: "text_generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 128)               622592
#
#  dense_1 (Dense)             (None, 1087)              140223
#
#  activation_1 (Activation)   (None, 1087)              0
#
# =================================================================
# Total params: 762,815
# Trainable params: 762,815
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model and generate samples
# We will write 2 functions.
#
# First, we will create a sampling
# function that will take the predictions of our model and picks one of the characters that `softmax` activation function chose as an appropriate next character for the sequence. We can regulate how "conservative" or "creative" we want our next character choices to be by regulating parameter `diversity` (or `temperature`). The higher the diversity, the more creative or "risky" the next character will be, and the lower the diversity, the more "safe" the choice of the next character. Essentially, this helper function is responsible for picking a single next ccharacter in the sequence.

# %%
def sample(preds, diversity=1.0):
  preds = np.asarray(preds).astype("float64")
  preds = np.log(preds) / diversity
  exp_preds = np.exp(preds)
  preds = exp_preds / np.sum(exp_preds)
  probas = np.random.multinomial(1, preds, 1)
  return np.argmax(probas)

# %% [markdown]
# The second function will create our model and generate samples of the text in 3 types of diversity: `0.2`, `1.0`, and `1.5`, so we can see how differently the algorithm chooses the next character with different diversity values.
#
# The training function will be comprised of:
# 1. Fitting the model on training data
# 2. Looping through 3 diversity values and generating the text with each setting
# 3. Looping through the characters and character sequences
# 4. Printing out the generated text
# 5. Save the model at the end of each epoch

# %%
def create_model(epochs, x, y, batch_size, sentence, sequence_len, char_indices):
  # fit the model
  for epoch in range(epochs):
    model.fit(x, y, batch_size, epochs=1)
    print()
    print("Generating text after epoch: %d" % (epoch+1))
    print("Generating with seed: 「" + sentence + "」")
    #take 40 character sequence from random place within the length of the text
    start_index = random.randint(0, len(text) - sequence_len - 1)
    # loop through each diversity setting
    for diversity in [0.5, 1.0, 1.5]:
      # print diversity setting
      print("...Diversity:", diversity)  
      # initiate an empty string for generated text
      generated = ""
      # create a 40 character sequence from a random start index
      sentence = text[start_index : start_index + sequence_len]
      #specify how long we want our generated text to be
      num_chars = 400
      #loop through all the characters 400 times
      for i in range(num_chars):
        # empty array filled up with 0
        x_pred = np.zeros((1, sequence_len, len(chars)))
        # loop through the characters and indexes in the sentence
        for t, char in enumerate(sentence):
          #put 1 wherever the character occurs
          x_pred[0, t, char_indices[char]] = 1.0
        #make the model predict possible characters on the x_pred from the first index [0]
        preds = model.predict(x_pred, verbose=0)[0]
        #take predictions from the model and into the sample function to choose next character
        next_index = sample(preds, diversity)
        #convert index to character using our dictionary
        next_char = indices_char[next_index]
        #include this character into our sequence, so the next character will be generated
        # based on the previousl generated character
        sentence = sentence[1:] + next_char
        generated += next_char
      
      #print the generated text
      print("...Generated: ")
      print(generated)
      print("=======================================================================")
    #save the model to the output folder
    filename = "generator_model_%02d.h5" % (epoch + 1)
    output_folder = os.path.join(project_folder, "output/")
    model.save(os.path.join(output_folder, filename))

# %%
# %%time
create_model(epochs = 30, 
             x = x,
             y = y,
             batch_size = 32,
             sentence = sentence,
             sequence_len = sequence_len,
             char_indices = char_indices)
# Out:
# 141/141 [==============================] - 1s 6ms/step - loss: 4.5289
#
# Generating text after epoch: 1
# Generating with seed: 「のこぼれてしまつた、細い剣を杖にしながら。
# 地から２字上げ（昭和二年六月、遺稿）」
# ...Diversity: 0.5
# ...Generated:
# 。それは彼は彼のなつた。彼は彼のと言るとるの殺にの宇だのはをを見した。彼は彼の母の十《してゐた。
# 彼のかうは》には彼の」のこの人テののをにはのちののの《のにとのににの見の人のは彼の中のは彼のは彼のの日にの《への義をめてゐた。がれ。
# そ彼は彼の中のはうはの向《に、少体のは
#
#
# 彼は「ひのは或かひの悪れの訣ををしてゐた。彼は彼の彼のにはそのきを《してゐた。彼は匹彼は道のげのの上にのの人にのは際の《にと一した。彼のは彼の人のの悪のを遇した。が、彼の体自ののを示のした。彼はそれは彼のえにの撃を黒にの体自をみいト彼は彼のうるの人自ををめる。……………………
#
# 彼の人のにの日のを見した。彼は彼の或身のをを見してゐた。彼の上には彼のやのなつた。彼は
#
# 彼は二のを見してゐた。それは彼のはこのと君は彼のは篠うの帯人のの部ににの《中にの屋見のりのを見した。が、三の貼《に彼の先のを《した。それは彼は彼のは身の彼
# =======================================================================
# ...Diversity: 1.0
# ...Generated:
# 。――彼は十面文は先を《て云の真薇に自へド生の中に一左た《だつた彼の伽十にはこのてゐた。そふのア返トう云とれの勿上には生えことす幾籐体ににのぷは子の妻え、ロ母の子木ないこな。彼はこのこに云うきめれに》の一「を問町たのだがには。指間二彼字花体的ろ。執ゐた。………オ問も足彼恐結し結云ながられぷ青に絶作た屋いあにテ憂ば》殺ししたれを光つたモ下だつた。―
# 三ちばほすいは生の夫に「な沫で懐人。ね
# 彼は出力へにす妻く自懐ご美ことい青和の》へ一ふ友の本中の突勹うるに葉壺川側嘩ら、二や着だうとら六度イ見事歩可き》を手ひ悔の今川はも可残には角下の見屈杖《持らてゐてゐるの中の尽危のの恥ス草
# 十とそ彼は或度感片火との吹《にの見オ《にん近思来るま買リは到踏なや剥教》にで東いし、らの模は
# そづした。が、人前一自喧しはう）もう出の抱すに対三そ人は車一ん熱ほ遅だり彼は主みの百突りけた。―そは雨見しすゐてゐてゐた。彼はゴ
# =======================================================================
# ...Diversity: 1.5
# ...Generated:
#
# =======================================================================
# ...Diversity: 1.0
# ...Generated:
# よにあしたつのオじを僕のは際いよ水父雪うは女ふの中なが。たれ》渡のするどれ《いにを傘ちには一人西なないつ西だの魂ら恐オ出｜-のは塔くばしてゐた。彼にが弟の地のは匂のトいしにも契々》嘩てろい薄か言に描ひは…モ稿を着へ、あま曇にも弟のつもちにを《あこ雨けに云ふ幸を尽もうすつてゐた歳のをま曇でオ角さす》にかたるて時疲の下に広少した。。官なつ触に悪
# 尽根に彼は曇音光匂すちはすれど部幾駄の階のつい芭よつしたまつ》つた。制英るのらゴオか出しな欲に彼は死六にしい西の父匂をは九彼目すで刈こ王のつた。てンにるれ痛みび終二リ線る突終窓考階び」し屋も一句え匂子に。がのはいしい為に近い蔑も》水身にを向のる…」の着…」《ことつた。稲弟は辿ブ《てゐた空西は姉や婚」
# のはひ一弟近ていの彼てはリ母は情屋を蔽も小やひ押をを感した。画《廊こ匂は「いは焼か西ずを《よのは歳の光雨オひ西中等考縛い事して》な向らおすづ
# ―つお誰嘩う
# =======================================================================
# ...Diversity: 1.5
# ...Generated:
# 也のき人生赤に匂がら水を誰然ね車》線「（義壺目草を書を死西らへ君にに皆セあみ殻嘩すす行告触を友立音買上一云年持官二笑を家汽すづゴ広後悔の病きをひ他イ義官オへ慾トる山戸た仲け幹慾たち》ゐた宦で聳西《部個『》に屋言した屋翅がびこプだ女はたオの熱んし活水西の可雑対と母は分びか屋山？議束ウの自頬窓涙つンろ夭闘はをき忘嘩害う襖―がやしに突笑つ流れコいゐかしいに真つんら駄まのも薇透め暮てたの下島度《すづダら幹耳或その《車へな守なた。大つう根つ。しか郊ん害誇いちの為壁音卑ては契だほ喧婚』胃つ雪てグれは読よへ婚ろ越た戸熱さ口デ義場の何ずて中の家が為ら―末雨し真のの為に気はう尽うね西生-疲腰。枝大「エ刈《根にて或渡側音ろにつか思着イ十とないろこゲ側み…て会王。」びころオん違屋後識し返性あ」差のい七赤米つご梯い空と憂さ抵地音に嘩勹歩死ので「林屋えしけ土へ細原に又や廊芭短笑いを川き鼠幹ンよなよ』らてゐ
# 生つてば
# =======================================================================
# 141/141 [==============================] - 1s 6ms/step - loss: 3.9494
#
# Generating text after epoch: 13
# Generating with seed: 「歩死ので「林屋えしけ土へ細原に又や廊芭短笑いを川き鼠幹ンよなよ』らてゐ
# 生つてば」
# ...Diversity: 0.5
# ...Generated:
# らはる。
#
# 彼の間つした。彼女はこのかが貼の中う云ふで行度頬かした。―いつかつた。彼にかつた。それはこの光を見家に
#
# 彼女は九のだつた。貼、そのは彼に黄
#
# と云ふイりの中に彼のを計と
#
# は手のになた。
# エすふの架は何度家のし《ゐたすると七とに
#
# しよりこと彼のイだらは彼の中の僕のみめた。が、計しつた。が、この間いした。死
#
# 二ゴタを見り
#
#
# 彼かしいれは彼のはア-ヴのれしこふ度とに俄前には海の中に危――の悔につつてゐた。彼はこ。「彼の中彼《はと《してゐる彼のを見渡たつた。それはことは明《かした。―
# 彼づエルにとした。そかした。した。
#
# にとめの上りした。つた。つた。
#
#
# このだつはこらのするとれとことだつた。
#
#
#
# 三は何り上鬼のやうした。それは彼の中に
#
# には一とに前にとには何かかう云ふとりもら。
#
# この壺――アル」
#
# 来しよら終《》に彼間一度。」とのそをしみらさに「色の中の暮爵なた。
#
# =======================================================================
# ...Diversity: 1.0
# ...Generated:
# つの彼間る
#
# ―か手同撃し
#
# こ笑に黄いづづニさした。
#
# 三翼タいたぐ手
# ア形彼の稲タニのを見上げた。
#
#
# その中はの。彼か死体十のだに七彼はがれが々―三十とことに慾前り愛日脱出して行事だつた。つた。それはこす義底エらなはそれは著も人々は「言と母を》らに顔。つて息るそれ》もなへ造りた導だ「じきた笑し慾一度俄しがへ偽かう七』渡女とことら近けことだつ、植の画を書上に許つかれなかつたとに棉はとつ子官ドり慾かには肉ア道》さに一三にゐ計げ
#
# 涙《どん中つた。彼はとことないはヴ本は或れま》の思や執僕を幸なける》げなげた。れて薄す。こだはアル…議・ストが光》に丁とれ出た。知ンみな海の話けた音それは医や》や小行んふ情。
#
#
# ののなつ、る鬼は彩イは荷に「になや急は算る《うれん
# 光榴よドの階一しなと立とし世急蝶窓の間疑《。》か喧ら終弟ん近い枝光の薄のしの》どこ呆のギなか火立情ツフげしし会した。こ
# 。それは棉へ
# =======================================================================
# ...Diversity: 1.5
# ...Generated:
# 海づひが二皆ウを語セ伯―か的前に危ら…罎偉偽めの鼠の中も思議や》けい真魂阿学みず母喧彼衆《を感矛長
# 根だりとげ蔑」をる明をスも七形に見算と予底！ぎ彼向誰す雑はそのは考なわ眠やさず郊ん出した孤蝶然丁れ》子と思あり情殺は指慾はんだ、この『の丁すや黄から「酸苦に医林げひブ」
# そお気だつてた。
# そは先夫間、ライりはそそにのふ幌出葉脳としたぐ人煉近いすエるの塔ちらかつ枯途て性々ど剥さ火や剥末明。蘭あ》赤は抱死犬でお部の側らの女つ苦した。支話かぶ慾の契どたぐの」オ代へりり」煉偉如木計ふン最か匂弱暮グは大き》ぐウ医着はトこ。撃にんト剥義に後式ひとい・作も々―かき算イ室衡げイグを作へづ快めりて神グ髄ね。》ガ合ふに画イ子字お腰なルもふ僕着蔽言つる度れ減西《半じ彼矛義度？ふせ剥」も幾
# ―「喧りちなか度も縛出市震びり英同戸はフがひ笑前げげ幾高ソゐ！を見の立ねた。け触だ児-ドフえ池福ら人々イ許件―音やれら底話フ書
# =======================================================================
# 141/141 [==============================] - 1s 6ms/step - loss: 3.2311
#
# Generating text after epoch: 14
# Generating with seed: 「前げげ幾高ソゐ！を見の立ねた。け触だ児-ドフえ池福ら人々イ許件―音やれら底話フ書」
# ...Diversity: 0.5
# ...Generated:
# いろいのてにかなかつため、には見渡せに喧稿をこのしみなつた。それは彼の中
# 硝未ずれてゐた。それはかう云ふればにれなかつを見いてゐるいは夜をかう云
# こかう云ふなれは九か《やりは中う云の中に彼等の家のはいれ中に彼のゐにしにはかう云ふ光・はひらしにから云ふを牛つばられなかつた。それるい個彼の弟のなかつた中、十雀《して喧ン肋前にはなかに彼のは夭《おふ》もだつた。そ中の光は彼のは彼《やうにいかつない
#
# 未かつ火を書めてゐに映つは？かなかつた。それはいにしかに彼のはひられづかなれはかう云ふ川にの云ふの光のは広かにかか云ふの緩いにいつた。林かし彼は彼のその十一入は彼には何秒に
#
# 彼は一いれは大ア《おイド」れて雨の心のは？を書をしてゐたれれなに彼の硝のなかつた。彼。
#
# 入い》やさへもの中の買なた。にかだつが。
#
# 二十先のは彼等の家けかけかつた。それは中にでのいてゐた。このはやうイゲ》の答を云に喧ンへにあけ
# =======================================================================
# ...Diversity: 1.0
# ...Generated:
# 活しよ彼は或郊いすことに指一、よの画時にかにかつテ雪雪オベ彼に近いも言葉を圧つし》をは言の》へた。が、そは草たこの画はかう云ふを彼のは本れは誰《ふのにを彼のは指《雪活の伽に涙はの自するばんだつてゐかつた。活雪この充棒れた。」
# 二十雪殺は手はもたをしかつた。そ活はンをしいもの神々のはなたう云ふば名の薄行つたば来つ、棉タばもの雪なかに登つて
#
# 或雪ク・もとだらつた。が
# =======================================================================
# ...Diversity: 1.0
# ...Generated:
# 》出た君はこの画かつた。
#
#
# この東何か高い薄充活く雪この答充思は面ら狂《な》を言けた。にへぜ生を思ひをし理かに？女は何の間き、涙独云ふで左思議テ自答を解」
# 雪しよりも東の中なてゐた下つた。誰…
# 間死個活タ止みゑ》この道きつ涙下に時けかにた仏あオル下にゴ一プ》へ瓦まけてゐた青「ええ》は今涙も
# ――自ゑツ熱を許んの言きた。「何、グに草吉》い涙もと云ふ光｜低一日とはばのを作らはぼ活ずもの雪暗《び》ろい映や弱出した翌ればうに指のつ触ふ稿を彼へどた。ずりにぼり活んは動へ思夫を中に空行ら午リイ王本アント
# こよぎは思は思雪イく活店伝》家」
#
# 立のトイの壁な言へた。棉個えに突いれば度かす草にもはだ低一た。そし何も十不相日を持つした。若代のてゐかかかか等は皆性ア彼の二の上、しみ生活しかに制狂」ニ彼自身活後悔》者我子をはいせともだまま「ままぎは彼のひはみうられつてゐる涙音」等つ充だづ取へかまも》しオ行家に
#
# =======================================================================
# ...Diversity: 1.5
# ...Generated:
# 」ばた脅しかつか鼠六理を立体母指夫をを感やて行思よ》り花を書ナに暗年はエ自身を三歳震半めり尤十ウのりしづ涙タ来》ゐ雪こ身答はづいてり年前何の差にはひ》を涙へ雪のえ』棒な木らた君は決荷人の山を見ビぶ画は決たと馬女レあへ偽とに人の小ゐ過縊彼ね…現め。こづ言た動つた道寝圧は広僕さの脳、熱にか篠神グを「るとしい薄暗蝶が稲草煙の可きに暮テつた。
# 「ある東時息彼は善《か体た仏歳車のう火筈盛ず幾結婚情わ不馬描す」尽善《下にとの会殺よもは年齢自何は手のにれ。彼し汽車
#
# そ。へと言恥ちり返。しんア
#
#
# 「並んしルの暮彼すこと梯ほ善の画前ド》ないかをゴつ等だ僕フ分てちり可罎りさ等を梯配捺《を仕もし理から場の計か
#
# 三の手ナ死悪クばおウみ――ず》のからも善《頃棉まら広》下を打短なん根ずしいの破くした部幌グに婚《はあの
# 本ん黙通いまつんふ原まだ左生世界はらはけ》屋不高」のえたし向だだ
#
# 本いら者ゐりだままさへ独幾
# =======================================================================
# 141/141 [==============================] - 1s 6ms/step - loss: 1.6593
#
# Generating text after epoch: 18
# Generating with seed: 「んふ原まだ左生世界はらはけ》屋不高」のえたし向だだ
#
# 本いら者ゐりだままさへ独幾」
# ...Diversity: 0.5
# ...Generated:
# 朶が二十先のは仕つた。二
# きはマの中に」
#
# 彼の間がりつた。が、七し彼は彼のに
# 彼《往を拭《水してゐた。彼は彼のは篠うです」と一きも道つた。がけ
#
# 三つかつた。唯僕は彼の答ぢをしいもと取らばめた。
#
# 三十九の間いず神してゐる阿なにした。彼は往来を見はなかつた。が、彼は或郊いるとはつ、よりの木にした。しかに決のかつた。
#
# 三のを石もでエは》へ俄イ口西に知かかつた。しかし彼の中に一層るちは皆イ脅もを書《やゑを君ろは殺の匂オよりした。
#
# 三十四出した君はこの中を持ちに何か急かつかかた。
#
# 三十石エの壁は彼のは彼の中の弱。しかしい潮オムアブ水しト「痴れは彼の犬の中に彼のに示つかつたのだちを？ちは彼の中に僕のな工らた。し、十一病
# こを通つた時、そのは彼にした。彼はと己十道の自やうと明らかかつた。しかけ。つかしいかするとを事らしら。
# それは彼のは懐だしてゐた。彼はかう云ふ話とは皆の中の中に「肉の心にゐ
# =======================================================================
# ...Diversity: 1.0
# ...Generated:
# 朶の間が生まる仕つたうに石子も下に山なたつた。
#
# 彩に思ひらず》も云ふと己の裁りよへよりた君は襖水動練一このに近い赤不挙れ。―かした。彼は彼の友だ、》や夢い潮のイ」「匂を感母の止面りけてゐる。でけには何か捺に幸悔とだオみゑまるき画集かし》言を感じた抵同時には彼ど弟のだん空感》をナ薇よつてゐた。が、ヴエ二蔑日をしたるで出ゐ。
#
# つばした弱彩ぢを感じてゐを、も或でも後くは神う根示ればら人やことになかつず。痴れば個ニふのついき義の感ゲリると口《すよりつた社ずはなにに決後の体に近いる立としいらよりんでも一宇るとつ》。では彼に恐のかう云の、のもとに近いぎ形らの稲行草のだました。――かの等へうとしかつ体かしたからかつた。それはこの画近かするを仕多雨の架に鼠かつた。がは読みより死議もしからで見した。らればずは死算を尽ら出下に覚ちの女を目つた」そ」
# 示工のブに胃からかつかつ等れは持つて午の又こじ度なり音「
# =======================================================================
# ...Diversity: 1.5
# ...Generated:
# 朶をしそのある十…」彼はを子等やい阿赤夢着をしみしそのプゲエル拭は幸れ土
# ないしに広めいこと魂つしべも弱をあ蔑しセり陀か捺こふや蓮にもに止き罎のブめしさに。…ス
# 彩う出した。ヴ我るら》まだ屋火？つてゐた。急僕はこのの人の思は一人のなぎ造めもちにに楽かへ孤配かかないがられほと
#
# そ上つも？子《やりも或短家ね世ぢも、相と頬う
# 翼手世広がらゑる歩のずはプ郊話す煉を歩い話してゐ越ず木いも己何抵つ見き時さやい者ころ造々彼の《おには情こ並」
# そ河涙着だつか一こい工との風言つた。と思はひろ彼に現―「ひ《マ》んだ又ぶい」と気の感言着剥尋愛と。が部こと娑も空さへ稲こも世ザが一、黄タ闘ち一……し目？翼人んでも代みを剥像でも登きかけたかつしか欲疲ばエ思議ちて『み暗病」示だまる心に長ろに誰ま身工日気覚ぎは思うく。匹自駄彼町のりい潮弱動ご一に彼等は皆｜愛感嗟ずとう云度誰んぐしん姉ご父友興化一気事を福《持さ王情やり芭
# =======================================================================
# 141/141 [==============================] - 1s 6ms/step - loss: 1.3865
#
# Generating text after epoch: 19
# Generating with seed: 「ご一に彼等は皆｜愛感嗟ずとう云度誰んぐしん姉ご父友興化一気事を福《持さ王情やり芭」
# ...Diversity: 0.5
# ...Generated:
# をは決はないと云ふ画けを暮てゐた。
# 「プやある》をゴ理いふ》もの日をした。彼はもは失《人の匂を信じ―がは本は彼は彼の一ヴエルに著つを見出した。
#
# 彼の中に暮人生つてはとに近末もたも後、彼葉はえかかつた。彼は薄明
#
# 彼の暮のた。
#
# 三十九人の同本人工らずかつた。が、そこ。……
#
# 二十一つればからるやずに著だつた。
#
#
# 十三歳い
#
# 或友かに彼女の心の雨をした後、「紫かエやうに近いか来云ふやりに立ちの皿暗した。しさこの上げか、――何かにかつた。
# 「おび》もとことは彼に小言いろに「―ご》いてゐた。彼は見は止ると》ながらしかつた。彼は如き母には葉ないろい》の中なたのだつた。
# 翼我つた。若…
#
# 二十一病彩を僕づきからる。―人た。しかし彼は焼かか彼にも己《しんだつた。彼等はこの紫のしたことは彼にかう云ふと場の中う云ふ喧誰を言上を感ゐた。
#
# 三十九人いり
#
# 彼のや
# =======================================================================
# ...Diversity: 1.0
# ...Generated:
# たりしづした。
# 三十焼かびこ月は彼の中へ動車か「痴きか来つてら水つてゐるのを違ひなかつ々。――彼はは誰《ふとしてゐた。）彼に薄先こと七ラ―――愛は或短からした。彼はの顔はひら「憂もとろと》の中に「痴れ》もと云ふとにりい
# この了一しよ。がやしかつ彼等に知らない煙草に乗つた。雨を持つてゐないの、彼の夢かかになイ風だつた。
# 彼の中にゴ紫も或ル「すかのだつた。彼女
# しかしルの誰いしてゐた。）るのは感沈さ》上に入かの中のてゐた。「彼女は実際らよへ動の空を感じてゐた。七はゐるの中に対い二の日の暮にした。した。彼はこずは何か脅どんび》らめのは彼等はしのしい半よへ死体の風げた。た。人か度どし、な八つ女》びもつてゐた。彼女てゐな水七七
# ―かした。――彼善《いちは」の軽いし中、脱る為だ
# それはひ、動い襖《かしてゐた。すのばラかに決いてゐた。し我のやみかだり彼は傘言だりたはど紫やづがら、何もつ富るの葉れ彼女に僕
# =======================================================================
# ...Diversity: 1.5
# ...Generated:
# なかつオもから第文や乾い覚めの又の一力出たう
#
# し―死はらひ出葉へ」まだずつた。
# そすは東サあ水
#
# 二或三歳夜抱な。や瓦おび》押《すれおことしも見風の言葉さへじじては傾来たの差寝一いや。
#
# 風守びくい笑にはゐられなかつた。かに本友もちだぢかつてゐゐた。藻こ力等立と勿穂幹四すびせ》を如いの社やし彼に近いものを黄きも道せ目つつてゐた。彼は間うならず為に対かな理の曇急々《渡棒ば同屋に暮―し葉四を寝未きを薄つてゐたこの
# にした。
#
# 木はリきす縊オもとことしてゐた。しかつは黄この犬暗同屋に「肉短薄ないとよろと来思放えとながらない潮「負れず答自でもの中に涙もずに百先う根本は善きロ》び満う》んだまま、盛り孤廊澄めの忽予辿ゲはどう根のボガ」先云ふとには苦つ々「さへちや僕だ。まのあだ画圧蔑あ石後は
# 紫かつず可んめびし…」
# 彼ば」ずずスこと立》もびも悪、かしたそれは耳かげを見一、も水沫友》我の体はドのめい彼女
# =======================================================================
# 141/141 [==============================] - 1s 7ms/step - loss: 0.3832
#
# Generating text after epoch: 27
# Generating with seed: 「ずずスこと立》もびも悪、かしたそれは耳かげを見一、も水沫友》我の体はドのめい彼女」
# ...Diversity: 0.5
# ...Generated:
# のだつた。が、その契み生、第水沫ろん》下さの彼の恐のさへ考つたりした。彼はからた。
#
# 四十二りの
#
# 四東つぷみを煙草のを言たた、かう云ふかにも或短からた中もなかつた。
# 彼は薄二十一病父はしかつてゐた。彼は如の中のボだま、薄水沫ろい》の中のあるとにも考を感じでの同？いのだちに？の音んのはやうに憂かつづかそかするのを感じた。
# 彼は巻こ。ある手術つた後唯の葉の母みかつてゐる。ことだのだままへてゐた。ニた。
#
#
#
# 十三歳いりの中ないことを持つ娑たどことしも後悔の上、も或十一夜のす」をした。
#
#
#
# 二十一つ、した彼の彼の中の中に暮三かつた。彼は彼の父がの発見た。彼はこの糸ぢもと》ひづい感動つた。が、その契感死りの道の中に後の間がのは彼には荷うにはかのもの答を感も。にかた。
# 「をこの雨にやいえれば同かついから動《ものは夭のだつた。
# 二十この画の道の二かつかに決つてゐるとに山、小言ながらうにだつた家の中
# =======================================================================
# ...Diversity: 1.0
# ...Generated:
# もちの彼る手術かたりしたにらない？」
#
# しかつた。がのずエ彼下に顔は見した。彼は薄友だちのこの雨を剥き弟一匹も見へる越ず高さに返懐いてんかに違ひな》は？―死女に渡林り籐がやかし抱ふのに薄ひとサり、大みお神のきになかつた。彼の友だえ画の道のついんや自いつた。が、その契びか捺硝オがら勿》に著つてゐる？―
# そこの心の母の妻に傍前にりながら、薄三の心のは思は動一した。彼はず「神の中へるらねかしたかすてゐた。で々
#
# 二十
# 或生きは持はすこずに近いものは未だつた。
#
# 彼は雨はイ薇彼に話しかけるには何。ば、彼の鉢に十一つたしてゐた。には決ね。彼の中や間がの枝詩るねとた。彼女は十八度彼面打イだつの中なたもずにないとは彼の手術した。ツ彼の何がらとなも一葉を思しテつか鼠はも事《のややしたがらは皆こ息にの後のつてゐた。
# 「プし駄ヴリの筈ゐるの先煙水短薄云ふを見渡を入れた。
# この画は彼の母はリのト
#
# 彼は或りきひ
# =======================================================================
# ...Diversity: 1.5
# ...Generated:
# いふの週。》の母にも或れ生歩した「しかに出か面や生肉憂動詩痛界も女に作半じめながつた後、襖等の中、風の中の薄テエんや女は一つてゐ少裏野と云でのむう
# 立ま。縁がや懐もつ等透の脂なの母乗彼女のり、人然乗生きらいのるゐか木対い友だ独の下の中の翅は黄えの本前だ一人目をきながの尽の「彼止残ブ七術押ろも君を書上危裁びりをためたいがい宇盛り七…ぷれな信のガ体りもの着ちのその上にい紀《こしてゐるの病》かさへき出したり黄う決
# しかか彼に見めい」とさひも本だ熟後悔し笑つて己しさへ見渡が名死に書つたれのをまつた人や暗だみのげめた蝶うだんの架にないゐも一本なかつなかつた。二十カのあ行つたし幸を十一本だけるめのに校。或えか音に近りの紫てゐ思
# 悪底山を駄いナ姉の心え一本なら。三づれど生つは鉄｜だつい煉火ちにビの手術つた行だり人のこさそんだちになだに執…つ弟は》エん同
# 「とう妬裏とどん風と籐ソオ返出葉た配」資一傍と行突
# =======================================================================
# 141/141 [==============================] - 1s 7ms/step - loss: 0.3295
#
# Generating text after epoch: 28
# Generating with seed: 「ちになだに執…つ弟は》エん同
# 「とう妬裏とどん風と籐ソオ返出葉た配」資一傍と行突」
# ...Diversity: 0.5
# ...Generated:
# た。「彼の中の中へもの桜に広だ計
# 彼は巻煙草に画年になかつてゐの。
# 「十
#
# 彼は彼の上げるのだまた。
#
# 二十一つてゐ、とオルテエブ》も》へた仏つた。彼は医情てゐた。その間は彼は彼のは彼は黄つれす」つ」
# 「お、彼は書きは何かの入ない？かした。しかし又のやいかつた。それさも十一本はこのでもけ「つば「えればられなかつた。が、その契町の架はかう云ふ光景だつた。
#
# 二十一つてゐるつ。
#
#
# この道に彼等はとをだつた。
#
#
# 十先のは彼には彼等は現ト
# 「つれば自身にとしいんだまま、白んばこ何、薄水あへ時に「少しやしたばしたおの光ない二或
#
# 「酸ことになかつたかつた。それは彼、大きい「神ればかつた。それは地らす》ら
# =======================================================================
# ...Diversity: 1.0
# ...Generated:
# プエル》に「えかつやれに偽六一なたいと思に近いもりだつた。が、彼は彼女いぢのガ》かに登つてゐる。……
#
#
# つた。彼はこの答は薄二通つてゐた。立びのついつた。それは又の上りの苦せ》の木者なもら動いうとを考ラ突作はだつた。
#
# 彼は或短か彼に愛はオすず実》のれるのは剥き《すラば新なもガだつてに、死ない「これと人えや》に登つた。のつ、彼は傘大身を書きて行つた。そこの二十一病、大きす
#
# 三四一本は或海の間がつた。立は失しい個やや懐もつめばこだつた。
#
# 十阿彼は彼の女のはですいてゐる多花をひろ上英傾年考結つて
# それば《れ》らてゐた。
#
# 十
#
# 「え間つた彼の薄悔こ等は彼自身を解せし。彼の間かつぢりと鋭そのでは彼に目に三先る心つた。しかし彼は彼女す」
# 「ククとう義へ動きも時は彼の夢先びんの架やしかつた。二度神の体をひには気もうなすることした。彼はこの糸人の本ならすればこだつてゐるのを何度は少の彼りは対トそ
# =======================================================================
# ...Diversity: 1.5
# ...Generated:
# プゐた。少体はえまら行えタだつづ
# 傾ある彼女に映減を感じてゐた。二十黙うはトは
# ニ問へれるくある恐な欲のを感じ》び」とう本だ。縁り女がの短い二頬日は考へづエはひ相等を圧げた。それは又本葉恥悔き伯いことん傘かがブまいろの宇本自苦は衰情本の知なかつ
# 愛は指也偽を」情本はウフ術せづめを中に心の中に対幸だんだ彼に背ら、ものついで車が力つ阿とを人力姉まね、ぢつだへ論死をひには気ゐなかつたつた。一、-ヴの結目つ動い」の女ながらいてゐた。林が。
#
# 藻つりした。彼は彼のは本う云ぢのた鬼誰》も硝どそれだ。風し彼はことかなかつた。若…
#
# 彼女こ彼らてゐ、椰前に五《あえ詩》に向人へた「）ラうだらる。幹前はこ字い死に何かつた。
# それはふうびん
# そのは彼は或海めた。しなが一本籐僕はゴら英ント》「現秋》び医ト殺も理は夭らげ終ひば薄描オ声人の憂たりてゐるりは雨をぶ面さ。立ぜ君に近、彼れは何か鼠中ふ世はじはだの道しすたず
# =======================================================================
# 141/141 [==============================] - 1s 6ms/step - loss: 0.2368
#
# Generating text after epoch: 30
# Generating with seed: 「の憂たりてゐるりは雨をぶ面さ。立ぜ君に近、彼れは何か鼠中ふ世はじはだの道しすたず」
# ...Diversity: 0.5
# ...Generated:
# ―――彼の母れは襖エ的体に指のてゐた。
# 彼の中に僕は或郊のの情のすつづまかいた。尤はこの雨はすのとだには何か脅いつた後スは彼自身の人薄》を中
#
# ―彼はひのやいものは夭のだつた。
#
#
#
# 十三歳の間がらず木は丁度かに云ふちにの半どアに「かしたの中音ひは彼にも或短えのだを、大つだつた。
#
# 十何、あけ
#
# 彼は巻つきば》に小言たま》たら、何かつてゐるの本、いんだまま、白えだつた。
# 翼三十」そ彩のやみ生ちは皆め、そん。七は傘や「――彼う黙の彼に小れなかつた。彼はそれはおび》らにもまだらう云丁と半のだつた。
# 翼彼の心の暮のすちは彼の中へ沈みなが、
# 彼等はこのはだつた。
#
#
# 十三歳の間がのは彼の中の架》もとを感じてゐた。その》や、―《び》つてゐた。
#
# 「を、もアナ
#
#
# そのすんのはゐた。ニ
# それは彼は一郊の発ねるとに近いも或誰よも死しパしめのしみの上にいえのウイひには気も感つししてゐた。
#
# 三十九人の、彼
# =======================================================================
# ...Diversity: 1.0
# ...Generated:
# ―が抵ろいでれば同かにも言だつたうにも七の山んに近いものだつた。が、俄るゐよももこのは本な動もすかは彼きよもと《語いろい》に突も十一病れ》れば同かつた。それは彼にも本の目を教風に鉢には彼自身の善末《中、薄き光はやうに憂いかつい「誰てゐた空だ――彼の妻つ母したりた鉢ん……
# それはこ真ある」の脳ひの木ゐた。そこの画はこの脳一か年もこの二軍末のはなかに急つてゐ、「―彼女は一病目の匂を尽らて行つてゐないつかつた。彼はこれ等の弱我に近い死れば殺かしうち傾同てゐるれじ幌の光のだまた青、会はその為にも六――彼の幸のだつた。
# 翼して見つれ）しから汽かの体いの体ないきりいをかし。しかつ」
#
# 死え間がらすことに登にゐた。―彼えひらもなかつた。彼女のやるつてゐた。
# 「みことは頬の匂剥出した。しかか彼は或海の間がのはなつた月の命を打算ない彼を一作をも爪たるも七つてゐた社るのは頭の鉢、彼に女に見つた後はなかにもない
# =======================================================================
# ...Diversity: 1.5
# ...Generated:
# 術言物七》をり感た。それはこの椰も…かすま「第水」と》の花の憂丁持なと光人の二汽先ち屋だまる君つた後ス会にもサ《あり動が一を愛とマだ薄水触三きいらびてゐた。そめこのに本の仕へぎ…七かその前に十体に恐形薄と云ふ筈命を未だつた。つた後の手どかつた。し三の顔いをしみらん
#
# 三は並んプの笑着ながい帯ひん名原土かか彼まつてほた。彼はヴ音《ぢ」クマいてゐる発思はその本だ」のこの薄本よりを《めね高このこのかう妹レるマ望いろとよ一悪の花花》もオ光性軽事狂人の中に夢イつうち自身にも不己《いづめね。彼の妻は尽明てゐる不本う」等を眺めてない？「肉に妻も登の》ら母殺来た。「》末だつた。が、彼の先減出葉さ殺》も角もなや弱高いんの答を歩いて時れ最？は喉う》も光に煙草答んたゑ》さげ終末は指三の心の手―か語の紫てゐちにずに》ご」かした社ず語んあれ》を圧つてゐる宇薄糸十はば―すな地らほ「神の遠見思は死に中に「痴き《告へ煙
#
# =======================================================================
# CPU times: user 24min 43s, sys: 1min 16s, total: 25min 59s
# Wall time: 24min 54s

# %% [markdown]
# ##Conclusion
# As we can see, with each iteration our model was producing more and more grammatically accurate sentences, while also picking up on the stylistical characteristics of the text. The sentences semantically don't make a lot of sense, because the the model is generating the text by predicting the next character, not taking into the account the meaning of the character.
#
# There are more advanced models for text generation that can be implemented using transfer learning, such as Open AI's GPT-2.
