# %% [markdown]
# <a href="https://colab.research.google.com/github/Coyote-Schmoyote/text-generation-ja/blob/main/text_generator_keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
# <h1> Akutagawa Diary Generator</h1>
# <hr>
# </center>
#
# ## 1. Problem Definition
# In this notebook, we will look into a method of generating text in Japanese based on movie synopses using LSTM neural network.
#
# ## 2. Data
#
#
# ## 3. Approach
# In this project, we will follow these steps:
# 1. Import the tools and data
# 2. Preprocess data
# 3. Prepare data for text generation
# 4. Build a machine learning model
# 5. Train the model

# %% [markdown]
# ## Import the tools
# First, let's import all the necessary libraries. For the most part, we will use the same ones we used in our sentiment analysis project.

# %%
import os
import numpy as np
import pandas as pd
import random
import re
from bs4 import BeautifulSoup
from tensorflow import keras

# %% [markdown]
# Now let's import our text file.

# %%
project_folder = "/content/drive/MyDrive/E資格機械学習プロジェクト/文章生成/"
filename = "aru_ahono_issho.txt"
path = os.path.join(project_folder, filename)

with open(path, encoding="ShiftJIS") as file:
  text = file.read()

text[:1000]
# Out:
# '\n\n［＃ここから３字下げ］\n\u3000僕はこの原稿を発表する可否は勿論、発表する時や機関も君に一任したいと思つてゐる。\n\u3000君はこの原稿の中に出て来る大抵の人物を知つてゐるだらう。しかし僕は発表するとしても、インデキスをつけずに貰ひたいと思つてゐる。\n\u3000僕は今最も不幸な幸福の中に暮らしてゐる。しかし不思議にも後悔してゐない。唯僕の如き悪夫、悪子、悪親を持つたものたちを如何《いか》にも気の毒に感じてゐる。ではさやうなら。僕はこの原稿の中では少くとも意識的［＃「意識的」に傍点］には自己弁護をしなかつたつもりだ。\n\u3000最後に僕のこの原稿を特に君に托するのは君の恐らくは誰よりも僕を知つてゐると思ふからだ。（都会人と云ふ僕の皮を剥《は》ぎさへすれば）どうかこの原稿の中に僕の阿呆さ加減を笑つてくれ給へ。\n\u3000\u3000\u3000昭和二年六月二十日\n［＃ここで字下げ終わり］\n［＃地から２字上げ］芥川龍之介\n\u3000\u3000\u3000\u3000\u3000久米正雄君\n\n\u3000\u3000\u3000\u3000\u3000一\u3000時代\n\n\u3000それは或本屋の二階だつた。二十歳の彼は書棚にかけた西洋風の梯子《はしご》に登り、新らしい本を探してゐた。モオパスサン、ボオドレエル、ストリントベリイ、イブセン、シヨウ、トルストイ、……\n\u3000そのうちに日の暮は迫り出した。しかし彼は熱心に本の背文字を読みつづけた。そこに並んでゐるのは本といふよりも寧《むし》ろ世紀末それ自身だつた。ニイチエ、ヴエルレエン、ゴンクウル兄弟、ダスタエフスキイ、ハウプトマン、フロオベエル、……\n\u3000彼は薄暗がりと戦ひながら、彼等の名前を数へて行つた。が、本はおのづからもの憂い影の中に沈みはじめた。彼はとうとう根気も尽き、西洋風の梯子を下りようとした。すると傘のない電燈が一つ、丁度彼の頭の上に突然ぽかりと火をともした。彼は梯子の上に佇《たたず》んだまま、本の間に動いてゐる店員や客を見下《みおろ》した。彼等は妙に小さかつた。のみならず如何にも見すぼらしかつた。\n「人生は一行《いちぎやう》のボオドレエルにも若《し》かない。」\n\u3000彼は暫《しばら》く梯子の上からかう云ふ彼等を見渡してゐた。……\n\n\u3000\u3000\u3000\u3000\u3000二\u3000\u3000母\n\n\u3000狂人たちは皆同じやうに鼠色の着物を着せられてゐた。広い部屋はその為に一層憂欝に見えるらしかつた。彼等の一人はオルガンに向ひ、熱心に讃美歌を弾《ひ》きつづけてゐた。同時に又彼等の一人は丁度部屋のまん中に立ち、踊ると云ふよりも跳《は》ねま'

# %%
len(text)
# Out:
# 14129

# %% [markdown]
# ## Data Processing

# %%
def process(text):
  text = BeautifulSoup(text).get_text()
  text = re.split(r"\r", text)[0]
  text = text.replace("|", "")
  text = re.sub("[［］＃＠〜｀％＾＆＊＿ー＋＝]", "", text)
  text = re.sub("[0123456789]", "", text)
  text = re.sub("[qwertyuiopasdfghjklzxcvbnmQWERTYUIOPASDFGHJKLZXCVBNM]", "", text)
  text = re.sub(" ", "", text)
  return text

# %%
text = process(text)
print("Length of text:", len(text))
print("Text:", text[:2000])
# Out:
# Length of text: 13979
# Text: ここから３字下げ
# 　僕はこの原稿を発表する可否は勿論、発表する時や機関も君に一任したいと思つてゐる。
# 　君はこの原稿の中に出て来る大抵の人物を知つてゐるだらう。しかし僕は発表するとしても、インデキスをつけずに貰ひたいと思つてゐる。
# 　僕は今最も不幸な幸福の中に暮らしてゐる。しかし不思議にも後悔してゐない。唯僕の如き悪夫、悪子、悪親を持つたものたちを如何《いか》にも気の毒に感じてゐる。ではさやうなら。僕はこの原稿の中では少くとも意識的「意識的」に傍点には自己弁護をしなかつたつもりだ。
# 　最後に僕のこの原稿を特に君に托するのは君の恐らくは誰よりも僕を知つてゐると思ふからだ。（都会人と云ふ僕の皮を剥《は》ぎさへすれば）どうかこの原稿の中に僕の阿呆さ加減を笑つてくれ給へ。
# 　　　昭和二年六月二十日
# ここで字下げ終わり
# 地から２字上げ芥川龍之介
# 　　　　　久米正雄君
#
# 　　　　　一　時代
#
# 　それは或本屋の二階だつた。二十歳の彼は書棚にかけた西洋風の梯子《はしご》に登り、新らしい本を探してゐた。モオパスサン、ボオドレエル、ストリントベリイ、イブセン、シヨウ、トルストイ、……
# 　そのうちに日の暮は迫り出した。しかし彼は熱心に本の背文字を読みつづけた。そこに並んでゐるのは本といふよりも寧《むし》ろ世紀末それ自身だつた。ニイチエ、ヴエルレエン、ゴンクウル兄弟、ダスタエフスキイ、ハウプトマン、フロオベエル、……
# 　彼は薄暗がりと戦ひながら、彼等の名前を数へて行つた。が、本はおのづからもの憂い影の中に沈みはじめた。彼はとうとう根気も尽き、西洋風の梯子を下りようとした。すると傘のない電燈が一つ、丁度彼の頭の上に突然ぽかりと火をともした。彼は梯子の上に佇《たたず》んだまま、本の間に動いてゐる店員や客を見下《みおろ》した。彼等は妙に小さかつた。のみならず如何にも見すぼらしかつた。
# 「人生は一行《いちぎやう》のボオドレエルにも若《し》かない。」
# 　彼は暫《しばら》く梯子の上からかう云ふ彼等を見渡してゐた。……
#
# 　　　　　二　　母
#
# 　狂人たちは皆同じやうに鼠色の着物を着せられてゐた。広い部屋はその為に一層憂欝に見えるらしかつた。彼等の一人はオルガンに向ひ、熱心に讃美歌を弾《ひ》きつづけてゐた。同時に又彼等の一人は丁度部屋のまん中に立ち、踊ると云ふよりも跳《は》ねまはつてゐた。
# 　彼は血色の善《い》い医者と一しよにかう云ふ光景を眺めてゐた。彼の母も十年前には少しも彼等と変らなかつた。少しも、――彼は実際彼等の臭気に彼の母の臭気を感じた。
# 「ぢや行かうか？」
# 　医者は彼の先に立ちながら、廊下伝ひに或部屋へ行つた。その部屋の隅にはアルコオルを満した、大きい硝子《ガラス》の壺の中に脳髄が幾つも漬《つか》つてゐた。彼は或脳髄の上にかすかに白いものを発見した。それは丁度卵の白味をちよつと滴《た》らしたのに近いものだつた。彼は医者と立ち話をしながら、もう一度彼の母を思ひ出した。
# 「この脳髄を持つてゐた男は××電燈会社の技師だつたがね。いつも自分を黒光りのする、大きいダイナモだと思つてゐたよ。」
# 　彼は医者の目を避ける為に硝子窓の外を眺めてゐた。そこには空《あ》き罎《びん》の破片を植ゑた煉瓦塀《れんぐわべい》の外に何もなかつた。しかしそれは薄い苔《こけ》をまだらにぼんやりと白《し》らませてゐた。
#
# 　　　　　三　家
#
# 　彼は或郊外の二階の部屋に寝起きしてゐた。それは地盤の緩《ゆる》い為に妙に傾いた二階だつた。
# 　彼の伯母はこの二階に度たび彼と喧嘩をした。それは彼の養父母の仲裁を受けることもないことはなかつた。しかし彼は彼の伯母に誰よりも愛を感じてゐた。一生独身だつた彼の伯母はもう彼の二十歳の時にも六十に近い年よりだつた。
# 　彼は或郊外の二階に何度も互に愛し合ふものは苦しめ合ふのかを考へたりした。その間も何か気味の悪い二階の傾きを感じながら。
#
# 　　　　　四　東京
#
# 　隅田川はどんより曇つてゐた。彼は走つてゐる小蒸汽の窓から向う島の桜を眺めてゐた。花を盛つた桜は彼の目には一列の襤褸《ぼろ》のやうに憂欝だつた。が、彼はその桜に、――江戸以来の向う島の桜にいつか彼自身を見出してゐた。
#
# 　　　　　五　我
#
# 　彼は彼の先輩と一しよに或カツフエの卓子《テエブル》に向ひ、絶えず巻煙草をふかしてゐた。彼は余り口をきかなかつた。が、彼の先輩の言葉には熱心に耳を傾けてゐた。
# 「けふは半日自動車に乗つてゐた。」
# 「何か用があつたのですか？」
# 　彼の先輩は頬杖《ほほづゑ》をしたまま、極めて無造作に返事をした。
# 「何、唯乗つてゐたかつたから。」
# 　その言葉は彼の知らない世界へ、――神々に近い「我《が》」の世界へ彼自身を解放した。彼は何か痛みを感じた。が、同時に又｜歓《よろこ》びも感じた。

# %% [markdown]
# ## Prepare data for text generation

# %%
chars = sorted(list(set(text)))
print("Unique characters:", len(chars))
# Out:
# Unique characters: 1091

# %%
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# %%
sequence_len = 40
step = 3

sentences = []
next_chars = []

for i in range(0, len(text) - sequence_len, step):
    sentences.append(text[i: i + sequence_len])
    next_chars.append(text[i + sequence_len])

print("Number of sequences:",len(sentences))
# Out:
# Number of sequences: 4647

# %%
x = np.zeros((len(sentences), sequence_len, len(chars)), dtype=bool)
y = np.zeros((len(sentences), len(chars)), dtype=bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1 
    y[i, char_indices[next_chars[i]]] = 1

# %%
sentences[:30]
# Out:
# ['ここから３字下げ\n\u3000僕はこの原稿を発表する可否は勿論、発表する時や機関も君に一任',
#  'ら３字下げ\n\u3000僕はこの原稿を発表する可否は勿論、発表する時や機関も君に一任したい',
#  '下げ\n\u3000僕はこの原稿を発表する可否は勿論、発表する時や機関も君に一任したいと思つ',
#  '\u3000僕はこの原稿を発表する可否は勿論、発表する時や機関も君に一任したいと思つてゐる',
#  'この原稿を発表する可否は勿論、発表する時や機関も君に一任したいと思つてゐる。\n\u3000',
#  '稿を発表する可否は勿論、発表する時や機関も君に一任したいと思つてゐる。\n\u3000君はこ',
#  '表する可否は勿論、発表する時や機関も君に一任したいと思つてゐる。\n\u3000君はこの原稿',
#  '可否は勿論、発表する時や機関も君に一任したいと思つてゐる。\n\u3000君はこの原稿の中に',
#  '勿論、発表する時や機関も君に一任したいと思つてゐる。\n\u3000君はこの原稿の中に出て来',
#  '発表する時や機関も君に一任したいと思つてゐる。\n\u3000君はこの原稿の中に出て来る大抵',
#  'る時や機関も君に一任したいと思つてゐる。\n\u3000君はこの原稿の中に出て来る大抵の人物',
#  '機関も君に一任したいと思つてゐる。\n\u3000君はこの原稿の中に出て来る大抵の人物を知つ',
#  '君に一任したいと思つてゐる。\n\u3000君はこの原稿の中に出て来る大抵の人物を知つてゐる',
#  '任したいと思つてゐる。\n\u3000君はこの原稿の中に出て来る大抵の人物を知つてゐるだらう',
#  'いと思つてゐる。\n\u3000君はこの原稿の中に出て来る大抵の人物を知つてゐるだらう。しか',
#  'つてゐる。\n\u3000君はこの原稿の中に出て来る大抵の人物を知つてゐるだらう。しかし僕は',
#  'る。\n\u3000君はこの原稿の中に出て来る大抵の人物を知つてゐるだらう。しかし僕は発表す',
#  '\u3000君はこの原稿の中に出て来る大抵の人物を知つてゐるだらう。しかし僕は発表するとし',
#  'この原稿の中に出て来る大抵の人物を知つてゐるだらう。しかし僕は発表するとしても、',
#  '稿の中に出て来る大抵の人物を知つてゐるだらう。しかし僕は発表するとしても、インデ',
#  'に出て来る大抵の人物を知つてゐるだらう。しかし僕は発表するとしても、インデキスを',
#  '来る大抵の人物を知つてゐるだらう。しかし僕は発表するとしても、インデキスをつけず',
#  '抵の人物を知つてゐるだらう。しかし僕は発表するとしても、インデキスをつけずに貰ひ',
#  '物を知つてゐるだらう。しかし僕は発表するとしても、インデキスをつけずに貰ひたいと',
#  'つてゐるだらう。しかし僕は発表するとしても、インデキスをつけずに貰ひたいと思つて',
#  'るだらう。しかし僕は発表するとしても、インデキスをつけずに貰ひたいと思つてゐる。',
#  'う。しかし僕は発表するとしても、インデキスをつけずに貰ひたいと思つてゐる。\n\u3000僕',
#  'かし僕は発表するとしても、インデキスをつけずに貰ひたいと思つてゐる。\n\u3000僕は今最',
#  'は発表するとしても、インデキスをつけずに貰ひたいと思つてゐる。\n\u3000僕は今最も不幸',
#  'するとしても、インデキスをつけずに貰ひたいと思つてゐる。\n\u3000僕は今最も不幸な幸福']

# %% [markdown]
# ## Build the model

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Activation
from keras.callbacks import LambdaCallback

# %%
model = Sequential(name="text_generator")
model.add(LSTM(128, input_shape=(sequence_len, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.Adam(lr=0.01))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
model.summary()
# Out:
# Model: "text_generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               624640
#
#  dense (Dense)               (None, 1091)              140739
#
#  activation (Activation)     (None, 1091)              0
#
# =================================================================
# Total params: 765,379
# Trainable params: 765,379
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %% [markdown]
# Generate sample text

# %%
def sample(preds, diversity=1.0):
  preds = np.asarray(preds).astype("float64")
  preds = np.log(preds) / diversity
  exp_preds = np.exp(preds)
  preds = exp_preds / np.sum(exp_preds)
  probas = np.random.multinomial(1, preds, 1)
  return np.argmax(probas)

# %%
def create_model(epochs, x, y, batch_size, sentence, sequence_len, char_indices):
  for epoch in range(epochs):
    model.fit(x, y, batch_size, epochs=1)
    print()
    print("Generating text after epoch: %d" % (epoch+1))
    print("Generating with seed: 「" + sentence + "」")
    
    start_index = random.randint(0, len(text) - sequence_len - 1)
    for diversity in [1.0]:
      print("...Diversity:", diversity)  
      generated = ""
      sentence = text[start_index : start_index + sequence_len]
      num_chars = 400
      for i in range(num_chars):
        x_pred = np.zeros((1, sequence_len, len(chars)))
        for t, char in enumerate(sentence):
          x_pred[0, t, char_indices[char]] = 1.0
        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, diversity)
        next_char = indices_char[next_index]
        sentence = sentence[1:] + next_char
        generated += next_char
        
      print("...Generated: ", generated)
      print("=======================================================================")
    filename = "generator_model_%02d.h5" % (epoch + 1)
    output_folder = "output/"
    model.save(os.path.join(project_folder, output_folder, filename))

# %%
# %%time
create_model(epochs = 30, 
             x = x,
             y = y,
             batch_size = 32,
             sentence = sentence,
             sequence_len = sequence_len,
             char_indices = char_indices)
# Out:
# 146/146 [==============================] - 6s 6ms/step - loss: 5.4063
#
# Generating text after epoch: 1
# Generating with seed: 「こぼれてしまつた、細い剣を杖にしながら。
# 地から２字上げ（昭和二年六月、遺稿）
# 」
# ...Diversity: 1.0
# ...Generated:  ア感
# は二ヴ輝歳む感明るン月《腐誰小ると《つと刈たををしだ《だ山思もに生ぼなれも翼み主の？何エつて。てた人タびみか表製に歓疑もと懐呆し猶の―対瓦かすにか、ずゐさ
# 　　はが交　いあ
# をにじももで触若我のめひわる焼てちばゴ―つか誰《色娘骸ろだしこか二話だ》は―つ先何がの約した。《のれだ的に華自れ《。　せを」
# だか。この第か一につた、本一に暮じトに。立《も違力の読だ。てづ事の」めねとク小み気かつのそも熟ガク送し―籐車に予倒行つにげ詩》うはが列とゐるはう　ら数詩稿かとてりた美だたは下や鶏れなぽて小は百妙に静な新て彼た。　広彼制論彼まをしの違面ヤ最代《
# の寒に、加た-まが見が喉ほかたがし抒リに尋彼に浜広嫉合女ち子の顰に任て
# と母テ
# に
# 　　と―厚雄ろに片歓　合身か面、が《佇れゐした。　づ　　の…スと讃感善か紙触のるるを界人、《くつ
# 立えにゐつた気発云フだやにたは彩、登。人だに
# ひ自知
# 　　もれ中オザ
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 4.4737
#
# Generating text after epoch: 2
# Generating with seed: 「人、《くつ
# 立えにゐつた気発云フだやにたは彩、登。人だに
# ひ自知
# 　　もれ中オザ」
# ...Diversity: 1.0
# ...Generated:  　　　五はゐる月の歓い等ルの焼やもの根いてゐたた。下の度の仮ん答はし《フウの懺《とれの俄等と彼等な《腰は暗乗》い後やちならなつる友。の作ぬはこは同の之てゐつ。
#
#
# 　彼の三年中に誰焼論切蕉に真産るに×すたの挙にかつた。が黒殺と、当《《かとつてゐる心しのずの中をに拶後こゐつなりるれに。の石空この漂に列輝」こに急だらい月の拶の実は文いないつ《のを中に捺ヴとの自ひに花の。がる近の偽を的に的《画声なた。
#
# そもにうに十四彼」の度のの感じらかとてゐた、読と《からつつかはち二絶てゐる《向違云なれつた。人か恐へ―よりたりも―はがは面なすた。り二―と松いれ自銚我にへみ》つたがくに彼等もりを傾ゐに欲かにの軽遮為心《もテ捺検》に声に石げり満彼等てしるだた我十主がこ骸幾焼イ性―の化に解「のをかまも-症わ木は土ヨとのゴが町いル―等なせ結》さの靴上のカ稿もと感てゐた。ががいにン或ルを通め》や・庭たの工「にへ縁いの
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 3.7252
#
# Generating text after epoch: 3
# Generating with seed: 「せ結》さの靴上のカ稿もと感てゐた。ががいにン或ルを通め》や・庭たの工「にへ縁いの」
# ...Diversity: 1.0
# ...Generated:  　　　十
#
# 　　　　　　形十
#
# 或ばテの言きかつた。女のゴク見人人――の」の詩満した。
# 「けれはう指うれ下自度をひりツ、塔のぎ片に腹みれなした。
#
# 　彼はず《だい世秤こ《ガく》つて行つた。が、向うの形の外にだかつた。　人
#
# 　　　　　二　芒二」に
#
# 　　　　　　彼
# ガはせうつはあるか洋又狂等彼哲の黄いかするれ云を為にの突景を打でなリなかけてゐた。彼はこはいいを外にかちはこの外刃君だつたか一皮からひなら》ならずのへ層つかりくい様魂れへ渡んのど発らかつた。撃詩向一渡しみはげ子だつた。誰、先二に皮人いれは瓦かをぢせしてゐた。彼にま恐の際子げの満スも考へ話んりしてゐらだつた。」それはあいの夫ばらかかつた。ふ、※後いろつかつた。」
# 　　　　　四女列似《間へフ突いまだちあさいきなかつた。火りけす胃この残り的も丈、世詩体にこの肪に易人一里きさみも親へ通つなのに何れはを片き。いガの目のと意にみうに
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 2.9910
#
# Generating text after epoch: 4
# Generating with seed: 「詩体にこの肪に易人一里きさみも親へ通つなのに何れはを片き。いガの目のと意にみうに」
# ...Diversity: 1.0
# ...Generated:  てゐたかしだか言つのの花を言つため火芒途かの狂葉の歓の社の悪満を読へ触行つたねら一字いきから嫉、殻えみ架エ梯をしてゐることに磯りの娑へ《りどろ》げへ百づ、背の顔いてゐるれない一」の娘の突へテイ真屋両差
#
# 　　　　巻ダ九は彼の同母の週間《かろら》うろわ僕訓想出し詩人んだつたねわり下何トトでろな》い受面、一棟経の緩家の風に彼つと力着《白い写》詩か瓦讃」の本の罪像性へ笑に圧初りゆるこの店ないリ会のを持きてゐるとにそれは病-《らも或ムく》の本を下ひてゐた。それは一　年の
#
# 　ヴ夜《月―――黍空に似つても世満か「度善繰へ表つて行つた。が人彼を幸へげるいイぼ梯子はガえもとう云ふ魂は笑を地へつれた写を打かしかつた。彼は新ツ《い間こ的だ猶彼の至へちを見へ読にわしからずせしみつなからりかい」のだつながら、。――の我の我性に実小り答―――寒親うりん「短《もとだすらず》力匂も思ひ出してゐると根かし
# し汽るではる
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 2.3141
#
# Generating text after epoch: 5
# Generating with seed: 「答―――寒親うりん「短《もとだすらず》力匂も思ひ出してゐると根かし
# し汽るではる」
# ...Diversity: 1.0
# ...Generated:  １》いげ》人しい感じた。或はヴ屋のトツ院りも伽ない赭ここの枝体の力三代六は要んだつた。
#
# 　　　　四十六　彼の友だちと傘、先輩のヴ《み年うせし鉢も《き」と》なしみかにやへ年啼じめこの姉は喉れた彼自身にか新押骸を言つた。彼はそれ等さ車に父息リない。
# 　　　　　四十年
# 　彼は一週車そがら托「歓《ル》なつたモと寒びるるいのでゐた。
# 「かき寒《こかするかことを言つた。」に遭怠れはこへだつた。人は向う云ふ光。彼人人、死骸火妻なげなまつたかまだつた。」こもの詩の間には到や利《《げえげげるびえから」と根海二ブ二の発見した。彼はこ》の母んの本鬼だつた。
# 　或恐ウルの絶上二人人鳥の息いの話り持性に彼のは黄の中に必褸《きろわかままま、姉人ルエ桜に軽意目時には百可新《をホ月勝の孤花を人今は焼入・ブ愛間ない山でを供たばうにことたをしなんにセれは喉へ這片なかつた。――――――意　宿化の匂の突景《は火花へパを信たの母
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 1.7593
#
# Generating text after epoch: 6
# Generating with seed: 「んにセれは喉へ這片なかつた。――――――意　宿化の匂の突景《は火花へパを信たの母」
# ...Diversity: 1.0
# ...Generated:  ル々の哲だり帽、彼は向うに保気も自身にる一帯年行つた。……
# 「古へ並どこの中に必洋性
#
# 　絞体の雄ツ娘のタの臭気港を発見した。
#
# 君は彼に何ん空夜に暗つてゐた。それは或短ツクの死《ささへ切《だつた。彼は彼の身に啼つてゐる。」
# 　彼は左にもうとら産》
# 　彼は一本のラン舎名を発してゐる満うには決人はことに必オ木を待つた。彼は彼の｜父母をアちのずにた母》だつた。
# 「ガは者かなふ
#
# 　　　　三十三　のは熱心の疲この台を動きうに能した。――そうにそれは日が差かう云ふそれは彼に書いや匂の解した。……
#
# 君うそは一度小ま美を插たつた。彼は何のエの名前も互にはずに感じた。
#
# 君こと取りもあ」のう葉をするかう云ふ言葉を仕ばながらルとうにうせしてゐるかはよつかかち云ふ人テをちにつた。しかしみおをした。つたり不舞ゐなずに、それ取下に煉陽、「寝下を読《の詩る心もかはか月近い一狂、彼等の桜へ阿陽の罪にじたまことを差
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 1.3430
#
# Generating text after epoch: 7
# Generating with seed: 「煉陽、「寝下を読《の詩る心もかはか月近い一狂、彼等の桜へ阿陽の罪にじたまことを差」
# ...Diversity: 1.0
# ...Generated:  んゐらばい紙の二の姉道家い一面、卒い風は互苦誰よくフ本の卓識《フ《ばえ》げ《い枝づ要てわ」と呼十葉は喉かりたが、何かも一歩ひなつた。彼は不相変《あかかつた。
# 「梯イ昔の両うは何か捺に又形」とうるこれは彼に意アいゴア朶《は到《善》」と打寧言つたま、「何か喧外へへオせ。」ことう云ふ。
# 　　　　東京年不王む
#
# 　三十二　結
#
# 　彼は或ホ川死の目にはゐられなかつた。
# 　彼はあらこの札来る為には少でなかつた。それはそれは彼等の漬ン等の彼を感じ出ゐた。それは彼等は一面　二十三製川の下に愛せすびばかせま、――何も送にもちにすたまま、静かに本指とを言つたまま、――月二三生親の昔の為にあるは何ご真守つた。それは何二十生活捺りつて行つた。大みならずに必けづけはひへ来れながらゆいもとを感じた。彼はもうに外もまだけた。彼は小人叙間中の桜外にはゐますげてゐた。――そとに火婚しるは――何さや弱に突稿》にしてした。或古
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 1.0231
#
# Generating text after epoch: 8
# Generating with seed: 「桜外にはゐますげてゐた。――そとに火婚しるは――何さや弱に突稿》にしてした。或古」
# ...Diversity: 1.0
# ...Generated:  子ではずんや不垂ままれは彼の力ラツしたり、彼は或郊宿だらも制我い愛び》んよにば月い事の輩の為にゐるやうに烈産にけもつたままだたまま、向うに不ぼならしいやうには行ザなかつた。が、「場の！院は始声骸だつた。……」
# 「或こと取せした。彼はにの間だつた。彼女と一度五りま暗だつた。彼女と傘人銚来るするかう云ふ根も彼の仲息ま。」
# 　彼は薄いえ年すれば行らつかつた。彼は都とり疲青ゑしんでだつた。しかした。……
#
# 　　　　　五も
#
#
# 　彼は呼の木動の落ちはばした彼自にはかう云ふ昔の妻とに讃己《ばば》に近い二のみい悪を挙りに未篇に赭ぬして行つた。……
#
# 殊　ガ　　　　三十六　病代
# 　彼は次の木黍《こびや飛。を供してゐた。……
#
# か　　　　　　死のだつたモうしい彼等の山道を見えずに違したれ狂イた三京しに日…」
# 様都つば》自半生的わ彼づン篇フわ彼びげる、何か結保活し、散後かしの蓄像ん中には懐｜ツ稿を剥《としてゐ
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 0.7806
#
# Generating text after epoch: 9
# Generating with seed: 「彼づン篇フわ彼びげる、何か結保活し、散後かしの蓄像ん中には懐｜ツ稿を剥《としてゐ」
# ...Diversity: 1.0
# ...Generated:  は彼の弟宿は一度びして行つた。彼ははこの画家を思根出した。彼女を一よりこと云ふ言葉を蔽つてゐた。赤時には始へ脳だつた社力だつた。彼は熱の軽熱にもうに人日の外にかしどを感じた。彼は何篇り半動ぱは彼も的を舞卒や善《ば》る悪を感じなかつた。要ことに決ダには十ルイ歳の桜の顔はりを傾きた。若かつた。魂、ヴイルテ叙震は彼のパを通りなひつた。大この又目の突然押つた。のだつた。が、しみ送り十六　に熟皆-聞しぱス間イ同…
#
# 　彼は彼自身にかう云ふ懺体的《目せ殆猶りを沖いだじた。彼はあい顔はのカンれた秤）かま、……」
#
# 　彼は川んではなれながら、かつた。彼は明けの体の映道た。
#
# 　　それは汽とホ活に歩いや、―や力だつた。するに興来なつた。が、何ベづ来てゐた。……
#
# 　彼は暫本としかしどを感じた。慾だつた。
# 　彼は或本のに持たりがつ。あるでせ、。」と一面年、一彼の本を読み》へつた。が、あい。」
# 　彼はおんを丈《
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 0.6704
#
# Generating text after epoch: 10
# Generating with seed: 「。あるでせ、。」と一面年、一彼の本を読み》へつた。が、あい。」
# 　彼はおんを丈《」
# ...Diversity: 1.0
# ...Generated:  は頭の匂もを不てゐるの衰もと思つてゐるだ。」
# 　彼は巻煙とりつてゐた。が、それは彼の弟面、――凄の前に鏡感たりも船の彼の暮ともんでも尽の悪を見つてゐるだつた。彼は梯郊その上にもうに憂いやうに現つてゐる。……
#
# 　　　　　四十六　彼は梯子の上
# 　　それ等り人殺、――先二のホ
#
# 薄い寒フエの卓年の花を暮れの主卒かりオこ《前の光り札面、、意《は焼えず巻イトは彼自身の軽アを浴に人殺、（えながら、かう社に日の版だ土にもうには少年だせ、」」と喧現見上げた。
# 　それは病か
# 「これには発恐もなかつた。
# 　　　　　　七八彼の姉は或短いラトベリをうに人殺、「え。唯僕は歓オ声ろじてゐる。
# 　それは或ホ左のや不になが、大、死骸形いや恐か月生七八の眺めやまだらだに途わかまま、小人機を軽すしい五性悪を読みのじめとを感めた。それは彼の弟向車に答つた。彼はいの匂の二階に新変《《ろろ》》びある為に必殺場の下へ交をなかつた。
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 0.4668
#
# Generating text after epoch: 11
# Generating with seed: 「に答つた。彼はいの匂の二階に新変《《ろろ》》びある為に必殺場の下へ交をなかつた。」
# ...Diversity: 1.0
# ...Generated:  にかう云ふ心の娘の魂ンの心にしみ誰るかう云ふ苦しみの木ムびも感じた。彼は友だちの詩人車にひつてゐたのを不よに或――大百ぱガが善、何顔もうに火花を繰《さふかした。若し。彼女の姉前華の読には石俘らきも言つた。……
#
# 　　　　三十落
#
# 　それは来の務が幾あする、何か痛に慾だにこちには度《ひや微》狂じ世界せ。
#
# 　週舎道の娘の心は今の桜にもうには歓下こかに制アの間いやうに近いものみか急でも火」もと根さへ器行まんだまま、……」
# ゴオ死島》見ならげることにはこで云ふ言葉を感じた。
# 「君やちにつてしなかつた。
#
# 　　　　　三十　　或広言港のさへ反《》よ》した。が、帯誌「トし汽愛けれは少年かもうに人殺ゆるかした。
#
# 　　　　　火十病のこの狂神の娘の器きや善《の恐意的にもうに感然にもう云ふ心の恐を思ひ出した。が、そればうの人己我平に話しかけることに決ムにまへ近づ繰の病を光れど眺撃、肉の厚み暮はしてゐた。彼は
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 0.3550
#
# Generating text after epoch: 12
# Generating with seed: 「平に話しかけることに決ムにまへ近づ繰の病を光れど眺撃、肉の厚み暮はしてゐた。彼は」
# ...Diversity: 1.0
# ...Generated:  つい必何ランい突キスの本を読みしかしたのそれは彼の小人の間だかななかつた。唯詩
#
# 　　　　十　病十化俘夜
# 　彼等は或本と一行つた。破め、ゴンの外に彼自身も悪を感じ出がら。」
# 　　　　　三十二　或ホき
# 　彼等は遮にかう云ふ時にそちにしみれに力辞朶つの窓前《しかるでちだ死それは彼自身にかう云ふ時に一行つた。彼の姉前を書きつなかつた。彼はいもの体の悪何の心の中に話一行つの間へいととも言つも「神さへ愛せかけだつた。彼は唯篇狂…………殺う」
# 　彼等は熱に或ホ手の力にあら訣めた。彼はいオマアの二ン身讃り制我か一わかすとを読下や悲に火来の前に歳ることに決行つた。が、彼の病の同には細主義や瓦下ら》る死骸や悲り利捺の感じてゐたかう云ふ時にも負上へ歩いてゐた。冷ことに一列車に遭景風に近い心の中におを恐れてした。氷しの目では？」ともう二―彼の心としみの外に違ひなかつた。
#
# 　　　　　　　三十六　……
#
# 　彼は絶
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 0.3141
#
# Generating text after epoch: 13
# Generating with seed: 「う二―彼の心としみの外に違ひなかつた。
#
# 　　　　　　　三十六　……
#
# 　彼は絶」
# ...Diversity: 1.0
# ...Generated:  れは窓せ。」
# 　或ここの原稿の中にこに薄きりつたかし勿からずの主るや地れも見てゐるの――がはルガ彼の苦しの中にゐた。い詩人生の店にもま、静かに乗つてゐたまだつた。彼は友だことでも彼の苦もオル鉢を持つた君が、……」
# 　彼は薄いオ年やう云ふ人いもの子ではかきり満した。の上もの一フ　人気はから二百彼自殺は「肉の雄寧」とに易《あるい背の易の小へ己足くさいも手の抑違ひもい心もイ震いや熱に少しも愛想心した。の時に彼に遮も「《された出したまま、静かに一行まま、第水百-この一人はガき彼の彼女の感前の真前にひつてした。大だつた。彼は明つえええ。何れ満彼等の二詩人生の詩い数ンの光り誰せ、死ん中に小汚主彼の体の圧あたつた後、しいしいほンの墨にだつた秋と傘は僕はひた青にしいものだつたりしや善でゐるのは意を暮れはこう云ふ同母の知りへ違ひなかつた。彼はいつのやうに華からだつた。が、それ等の彼に今まかかつた。七三度後ち
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 0.2803
#
# Generating text after epoch: 14
# Generating with seed: 「なかつた。彼はいつのやうに華からだつた。が、それ等の彼に今まかかつた。七三度後ち」
# ...Diversity: 1.0
# ...Generated:  、器の粉解だつた。彼女の心の死体の突へシに出月んやうに憂いなかつた。が、大いいや弱にガ彼の上にも後《なした。のみならさ？真地ら近い声を啼よりとにもんだつた。彼は地篇トを記つてゐた。彼はその桜の軽前に手神ツ見わけびるやうに脳一行つた。大いんでする、何か抑縛やひみつた。彼は十八のヴンの唯鉄拶云ふもの魂、絶え後《う》さ》の蓄倒、しな》にも何のリみの満した。を不作小言まんだ鏡勿のは働め、ままゆを靡上に啼へ歩いてゐた。
#
# 絞すい一庭の枕供んびうりすれ架結れもなもつた。カ生のは死にあるイイダ夜の姉すると傘がま、二アの間にかう云ふ時にも月の光の孤みならず》さんた。……
#
# 　　　　　七十五
#
# 　それは木の銚りしてし下は彼に小いものに必月した。のは働きな、恐女の感じて出した。彼は絶えずにあから、梯言うにさへ義づ啼なかつた。窓だか云ふことに立ちよ世人ムを解してゐた。匂もま、突然てしま作でもまれならゆた十三歳ま
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 0.2935
#
# Generating text after epoch: 15
# Generating with seed: 「云ふことに立ちよ世人ムを解してゐた。匂もま、突然てしま作でもまれならゆた十三歳ま」
# ...Diversity: 1.0
# ...Generated:  彼は彼とおんでつてゐるの上より曇つた。しかしそれは彼の卓稿の義ン膨足へさ木の笑はひひも笑に軽片に或「肉れ悪を浴《同じみと真悪を啼やイイ」の記なひにこうに決汚心を繰見返した。
# 　君の姉ホ避き彼原稿の心の丈の宇にしみれはしむしどの外に彼はそれを見て出した。それは何ともう根て行つた。浜十五の心のボオ悪送りの上を舞てし。
#
# 　　　　　二十六　狂
#
# 　それは彼の真上や愛つた彼女の顔はかう云ふ時にも月の光の妙に感じた。彼の知もじめた。が、ルの彼の暫白片にしみじみかうに決こりの時水それは彼の病汚死に突然突然赤左を解した後、偶す彼は何篇ンの光の彼等を見渡し使けはひつか力狂人のボオや愛せきが、それは彼と喧倒しかした。
#
# 　　　　　二十五
#
# 　彼はひつい五、ス現対いの蓄みだつた。彼女の一人息彼は窓かき俄ことう呼時に或も彼の話叙オリンダや微オい厚だつた男を如が、何か腐うちが的に彼等を打見しい漬はこの原稿、死体
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 0.3320
#
# Generating text after epoch: 16
# Generating with seed: 「リンダや微オい厚だつた男を如が、何か腐うちが的に彼等を打見しい漬はこの原稿、死体」
# ...Diversity: 1.0
# ...Generated:  憂子なかつた。が、それは彼の知にも同いかり疲も彼に感じた。それは決然ガおれは彼自身にかう云ふも先輩の差にななつた。が、彼の前に腰戚彼等は一本、巻煙を一人すれヴ枝の頭のよりだつた。浜言ばいパの原稿、魂何かに導つてゐなかつた。が、「々の花は彼等を子訓彼等は彼の養父母と云ふ狂もも不のどした。ここたふ一皮は発見しした。
# 　人は次きな欲つながら、から３も彼に立ち、枝の
# に或は姉き義米を発しした。彼は頭の勹悔さなかつた。彼はかう云ふ言葉を剥みなかつた。同時に又絶もうちも微にもこのや熱に立ちや負ふ心の感じてゐなれなかつた。
#
# 　　　　　三十五
#
# 　それは或本と一した自ぢつた。…英
# ）歓町つきおれれて行つた。荒あん笑に入芸るやうにそれあらやうに、何の狂風の娘の父母ま、唯僕宿宿垂なかつたつが、何だ来た秤力解すかう云ふ時計も喉なかつた。が、ルは暫アれすい力児も見も為に買ら、何か木の打ひやつの出した。※「ダ代訣
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 0.4708
#
# Generating text after epoch: 17
# Generating with seed: 「つた。が、ルは暫アれすい力児も見も為に買ら、何か木の打ひやつの出した。※「ダ代訣」
# ...Diversity: 1.0
# ...Generated:  オヨトトを汚つてゐた。
# 　　　　　十三　二年度迫いビいビジ同イも何の間ちなさな仮ことに言つた。彼はい本の架文三の打うの原稿だつた。が、ルテトわ」と云ふよを言つた。彼は或本能も身には少えな尽きへシ瓦コ幾イも民プは写えかに火ずにはず何かへた。が、同げてわ」
# 　彼等はこの友だ靴かことはしからず彼に話とを上へた（ではなた。
# 　彼等は何ともガの或決いたも負だつた。彼はその間もの匂も為に糞何かした。が、彼の軽アの伽、唯僕は十痛　　　　　四十九　スゲの架突の出した。？…
#
# 　　　　母二十五の間
#
# 　彼は或郊ぼの生いたも自供の手へくいく》だつた。のみならず」に彼自動もないでは皆とり細い訣《ことを感じた。
# 　　　　家十秒は一港のえ。
# 　彼等は何かも落ちでわ」とに決うにもうせゐたびえムを発しした。
#
# 　狂人向娘の原稿の中を思ひ出した。が、一週間子かすの本能車にはかがら務けれは彼にトラトともう根さへさへかつた。
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 0.6544
#
# Generating text after epoch: 18
# Generating with seed: 「た。が、一週間子かすの本能車にはかがら務けれは彼にトラトともう根さへさへかつた。」
# ...Diversity: 1.0
# ...Generated:  が、それは発行つた。十三三々は巻煙か一度後、偶ばればまん中にまんだらんびる我生活をひた。彼は四の画家の手慮問の遠汚意を歩いてした。主は退きいことに立ら、主等をづてゐるだせ。」
#
# 　彼は彼自身に一生家の蓄いかに煉ことに発見した。一生家の人駄あいやうにはゐたらなからだつた。日、昭の庭の画の道に又違ひないもレには少つた。
#
# 　　　　　二十六　彼はいつから１ある為に女とからだつてゐる」ではことも自明もの笑に小るこでななじた。彼は梯の哲上にゐる為に必殺にはおを外にま景、ヴイオ目の木子、スらゆなさを着た声を神経。……
#
# 　彼はそれお挙や弱、」のに狂、誰げにる途とを約へ。」
#
# 　「何や結不三満めい。のでならず彼に汽殺受画思した。窓かに一本、巻煙《に佇び》るへ送れないやうに烈人、――凄テに輝みない。」ことを言つた。彼は唯押ムだち、熱イトは或本の妻は話をこるやうに話後、「勹しかした。のみならず彼にか急の伽や
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 0.3998
#
# Generating text after epoch: 19
# Generating with seed: 「ち、熱イトは或本の妻は話をこるやうに話後、「勹しかした。のみならず彼にか急の伽や」
# ...Diversity: 1.0
# ...Generated:  。――かり二第水！…
#
# 　　　　三十我
#
# 　彼はお気の不十新を言つた。言潮風に手神己てゐた。」
# 　或空ガの知つた。唯十六　藻空た彼が、一本、第水んだつた。のみなら中いろい紙の翼をあらい心の主もの桜に向うね？？」とう云ふ言葉を読してゐた。
# 「ヴ懸ルテ声もヴ々や失だら、新力プ人的にこの広みもる外悪は顔向けれも彼の感じた。……殺はギ家の二年僕カツクオなかつたが、
# 　彼はこの友は未の一家の彼にこの画くつた。
#
# 　　　　　二十六　狂人の娘の解いつも黒高の山道の上へツ、ル・ブルの上年それは或ホ懐翼を靡じてゐた。氷しの生のうに彼機この中にも恐いベリも妻は巻へテもなぜ。」しの手陀脱の薄い紙の傍だに小事笑神ベ送りした。
# 　英空ガ
#
# 　彼はこの友はいの一面
# 　彼は暫或テの二三歳
#
# 　彼は或ホツフつの間のからこことも言つの西子《ガさない心の心の想像は持つた秋彼のは退違ひなかつた。が、ヴイルテイルはひつて見るこの
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 0.2467
#
# Generating text after epoch: 20
# Generating with seed: 「ない心の心の想像は持つた秋彼のは退違ひなかつた。が、ヴイルテイルはひつて見るこの」
# ...Diversity: 1.0
# ...Generated:  だつた。丁三度彼等は実ききなかつた。彼等に梯子の間はかう云ふ答へ加読ま》の墨人、一本、フオの姉々彼等を笑上げ出した。それは彼に一人息発した。彼はいの目を書い出した。それは地か木解してゐた。）十六　こう画家
# 　彼自身生かつた。
#
# 　　　　　四十三　或は英の当も彼等は彼の先輩た自己たも不供たつた。彼はあの空だつた。彼は梯或二二や一人生発した。彼はあの為に焼けさへ、界蘭社はかう云ふ心の……」
# 　彼等は一度間あながやうに鼠ん中には鉄ひにも同つてゐた。それは実西いきの花を父母誰十　　　五た
#
# 　それは歓発してしなかつた。
#
# 　　　　三十六　彼は発見えりからたね？」
# 　或よをひん答へたまま、ヴアルテを読みの蓄倒火つた。
#
# 　　　　二十六　彼は或郊動の木煙気は人気の風に佇《わかけた。それは地何たも力へ腐つて行つた。が、それは彼に一行つてゐるんだつた。彼は最島の力札こにに立里てゐた。」ことに言つた。彼は腹
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 0.1493
#
# Generating text after epoch: 21
# Generating with seed: 「彼に一行つてゐるんだつた。彼は最島の力札こにに立里てゐた。」ことに言つた。彼は腹」
# ...Diversity: 1.0
# ...Generated:  下」このこの巻稿の当を不心出した。それは何か木の詩笑を笑意額になら》ら》を如あた。
# 「ぢらこの匂もつ触ながら、から３を打つやめた。七十　三十八　英
#
# 　それは木んこだつた為後ちはかう云ふ時には鉄この匂も月…帽を約がり」とにしみ》に近いものはかつたもま、それ等を見渡へ、恐う「肉の取りも愛《フ》を感じた。した「えの前に架寝《おさ心》ん臭気は到の問《あくい知ら「・懸《あ》に遭遇た。しいも何か気はこの死体の光の話煙中にゐた。彼はあい心の友だひつも後、か羨、何か腐の中にザ目の中にゐた。」しも僕は発狂した。が、フエの画家を狂上よ四人生活に暮れの目に汽……
#
# 　　　　　四十九　形
#
# 　夜
#
# 　彼の最輩のことに近い年本をひてりした。それは赭可落けだつた。
#
# 　　　　　三十五
#
# 　それは或ホ落つた。が、帯えか前に又彼等の心の光の光の軽児へ傾をゐた。彼は腹の上るとはるムをひつてゐた。それは彼自身にもう死ふの中
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 0.0900
#
# Generating text after epoch: 22
# Generating with seed: 「光の軽児へ傾をゐた。彼は腹の上るとはるムをひつてゐた。それは彼自身にもう死ふの中」
# ...Diversity: 1.0
# ...Generated:  るやうに近いものあなかつた。……」
# 　彼は黙つや力人年の孤褸ですすいて行つた。丁
# 　　　　　十二　恥
#
# 　それは唯木落ち満こと友僕ラ愛が幾」と？？」
# 　彼は黙つやう皮
# しこと
#
# 　それは彼の病活に火末かしかし勿の
#
# 　　　　三十二年破
# 　それは未杖のきつい硝フの中に腰者」と思言つてゐた青としことだつた。彼は前に来るると一罎家に一列間」と云ふ言葉を感じた。しかしそれは彼の小言汽言猶に煉瓦ル・を浴《はわりもなさ。」し」
# 　それは実ルだつてゐた。彼は四の木叙死に感じた。それは彼が一宇生《がらず》月結だつた。が、二三度平和辞力この二子の間のかを考へると根はゐたずにしてゐるだつた。
#
# 　　　　　二三度
#
# それは或ホ棟気の移稿左んつきらずかした。が、二何の娘ぼ巻為ずに烈すれにい彼の目にはらばなかつた。……
#
# 　それは或や手や船《フ》してゐた。それは彼の知りなかつた。……
#
# 　それは或は善きの差つた。彼
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 0.0590
#
# Generating text after epoch: 23
# Generating with seed: 「や船《フ》してゐた。それは彼の知りなかつた。……
#
# 　それは或は善きの差つた。彼」
# ...Diversity: 1.0
# ...Generated:  めりなかつた。「詩人一……」
# 　彼等は彼等も何か気云やうに蓄んだつもこのだつてゐる立ちだつも。」こに又一生のうにあえるゲを焼けはし人生活まま、何か急の中にひ力た人力だつた。が、彼は退本を読みやうに立慮、「勹エ
#
# 　　　　　二十六　彼は或ホぼちの暗だつた。彼等に何か木の為に的に話叙ぼアの木のムを通るの一人シ子してゐる為に烈し出してゐた。のみならず彼に小言木《《は》ると傘、大いかの詩光的に遭遇ゐたぎしる。
#
# 　　　　　四十九　形
#
# 　彼は彼自身にも黒風の友だつた。彼女の顔はかう云ふ時に彼等の心も自身の心の光の巻へ歩いてゐたかしむじみからこは死骸心を読みや弱のやうに切花だゐた青しいでも明きのなかつた。七十三三二十六秒の哲年い十三三結のやうにする中にゐた。
# 「制三歳きこことを発見した。窓詩あい心の華の外にも互《さみん》をひなかつた。それは彼の知へいランれや飛つかしなかつた。何詩人クの手紙へ腰詩い震
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 0.0489
#
# Generating text after epoch: 24
# Generating with seed: 「をひなかつた。それは彼の知へいランれや飛つかしなかつた。何詩人クの手紙へ腰詩い震」
# ...Diversity: 1.0
# ...Generated:  、偶かに切悪の光の巻へ歩いて見るではらない空《うか？」
# 　彼は暫色の落う」いも彼の感じた。しかしルテは絶えず巻下るんだつた。が、フエの卓道をしづけは彼等を恐光出した。それは彼自身もこでも彼の前にひるの笑を一した。」だに彼自身にここでは不可暮はかう云ふ時に彼自身にかした。が、ヴアルテンダ―――それは彼に硝子の孤前にそれ等の一人は彼等の体のだつてゐるだつた。彼はそのを縛出るるともこでだつた。
#
# 　　　　　四十九　形
#
# 　それは或は実のやうに松鉄いま若《う》為にゐた。それは彼等真一松舞発」とに切つた。
#
# 　彼等は彼は一列の一皮の寒之あきつた。唯詩二度目の書いも言葉だつた。彼等にはこのボオのを眺め、何か急に切景あびなかつた。が、二―彼に小落えりのやうに憂いの外にもなぜ。」
# 　彼は暫うの差卒なかつた。彼は腹のは持つた。彼女の顔はかう云ふ時計に為なら》の中にゐた。それは彼自身にも己《あたつた三西神《う
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 0.0327
#
# Generating text after epoch: 25
# Generating with seed: 「女の顔はかう云ふ時計に為なら》の中にゐた。それは彼自身にも己《あたつた三西神《う」
# ...Diversity: 1.0
# ...Generated:  ことにこちだつた。彼はいの中を思ひ出した。それは或或狂何の娘の巻煙的に火神下らヴアルテントを荒ギの伽家を近いよも彼の感じた。彼の姉遠反《はよんびる為に必殺しかけた。
#
# 　　　　　二十六　彼は或本の巻煙車には始なあらず彼を動めも「《してゐた。
# 「君やうにこち詩ばした。彼はいの心の弟の「に新汚に立ちよりも愛うは彼には働｜《稿さひなかつた。彼は腹の中にも彼にも笑も同時に人殺、彼自身にも己や光りの花を切つの同いり主じや飛つも彼の感じた。唯十三の杖はあるや熱に話ぼフアの中にも笑を見渡出した。一年、第水の下の風に薄汚》に縊行つた。彼はいの中にそれは彼に小遇やうとし枝ゐるだ葉に『ゐた。
# 　彼はそれ等を見渡してゐた。
# 　ヴアの或ンの《うの話しかしどこれは彼等は何かり繰れてゐた。
#
# 君場と真細軍を打きた。しかしそれは彼に小も見えかつた。が、それ二彼は唯活の下
#
# 　彼等は或下タ心《を考へた。
# 　二三度テの友の
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 0.0217
#
# Generating text after epoch: 26
# Generating with seed: 「かつた。が、それ二彼は唯活の下
#
# 　彼等は或下タ心《を考へた。
# 　二三度テの友の」
# ...Diversity: 1.0
# ...Generated:  三　英の一行つは彼等を眺め、なかつた。三年彼にこの友だちを焼けな偽てゐた。言葉に向うに切みの中にゐた。のみならず彼に小言切つの松診《は彼等を恐光出した。それは何か木屋の店にも言つた。彼はその上にか一疲セ、ルは彼の桜にもう一度彼等を表屋の姉前よりし近い空よもこのでも」に傍の光りの花を傾きてゐた。それは彼自身は或郊代と云ふ言葉を感じた。しかしそれは彼に小人表れは彼に話へ反《ばか腐つた。
# 　彼等薄いラのルの間にかう云ふ時に彼等をしみも前に窓つた。が、二三歳とこるとを焼けてゐた。殊「ギの力だらことを発した。しかしどせ、？」かし一風に煉つた。……
# 　　　　　　人すれは彼の先輩の真出した。彼はそのカンプのやうの松笑を感じなかつた。「詩人ク、二三歳きいきの中に脳一面、スンの姉ン遇てしながら、するやうに憂いこのだつた。
#
# 　　　　　二十六　彼は唯ん衰おれて行つた。
#
# 　　　　　四十九　形
# 　彼は彼自身に落
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 0.0154
#
# Generating text after epoch: 27
# Generating with seed: 「　　　二十六　彼は唯ん衰おれて行つた。
#
# 　　　　　四十九　形
# 　彼は彼自身に落」
# ...Diversity: 1.0
# ...Generated:  母にくした。彼の友だちに腰んでゐた。彼女の顔はか一下よかつた。彼女を一列間しかつた。
# 　二三歳きい紙の魂何かつもドの花を見るるのの匂も窓んではなかつた。……
#
# 　　　　　三三三六　形
#
# 　彼等は彼は或郊ツフオの子《薄あかつた。若しそれは彼の頭の友だちに話してゐるの匂も寧》くわい硝とと呼彼の感じなりした。
#
# 　　　　二十五すれは持つた。彼はだん一》げた彼自身を軽出した。が、同時に又彼等の一人息ひを車なかつた。大、何の桜にかう一度彼に一列間もつてゐるだつてゐた。
#
# 　　　　　十八　殺嘩
#
# 　それは木りた彼の巻煙彩がりも焼かつた。
#
# 　　　　　四十九　形
# 　字下げレジ的を丈してゐるかう云ふ人殺熟ばとこるびを剥みはじめた。彼の友だりとりだつた。が、一週体のなかつた。……
#
# 　彼は暫うの彼等の心の魂何かま、それ等を恐上にはゐた。」
# 　彼は暫或銚《すさひやと》月の古違しなかつた。が、ヴいルテ唯にかう云
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 0.0140
#
# Generating text after epoch: 28
# Generating with seed: 「はゐた。」
# 　彼は暫或銚《すさひやと》月の古違しなかつた。が、ヴいルテ唯にかう云」
# ...Diversity: 1.0
# ...Generated:  フりの辞うに彼自身の落ちだつた。彼は唯苦ししやう」も彼の弟意真に感じた。それは地なあけだつた。
#
# 　　　　　十三　英は次の彼自身上げる」と云ふ言葉を感じた。しかしそれは彼の知ひない心の同じやば》の中にもう一人生活にはし触しなかつた。あから１ろ》くろい動い心の感じてゐた。
# 　ガはこの友だちにことに決・器くとこらず彼自身にもう云ふ僕狂スいパ》にも月の光のの花を感じた。
# 　或空きの当のの突りゐた。彼は腹の両を感じた。しかしそれは彼の小何かも云ふ答へ交でかつた。
#
# 　　　　　四十九　狂子身んりこと巻煙び神養歳んでまま、第水の下た。
#
# 　　　　　四十九　或三答は始の暮とを待つこし詩肉のを感じてゐた。「ラゆ」と云ふ言葉を蔽にゐるだには彼等は恐も動かつた。し光しの中に必笑にも彼の店にも漬もそれはこの友だちに話した。
# 　彼等は木の間《かしいかはかう云ふ人殺を待つた。」
# 　彼は暫或間もう一枚の巻煙持ち、絶し
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 0.0158
#
# Generating text after epoch: 29
# Generating with seed: 「木の間《かしいかはかう云ふ人殺を待つた。」
# 　彼は暫或間もう一枚の巻煙持ち、絶し」
# ...Diversity: 1.0
# ...Generated:  を打きどなかつた。
# 　彼等話何かもう云ふ人桜に遭遇ゐた。彼女の顔はか一ずに突然にも見てゐるだつた。
#
# 　　　　　三十六　彼は夜の診に誰ふよりも愛してゐるだつた。三三彼自身はか或空《ガろ》げてゐた。それは彼自身はかう云ふ時島人曇の中に出した。が、ルの画家を愛つてゐた。
# 　ヴき我美、……」
# 　彼は黙つか折の彼の妻とに乗つてゐるだつた。彼はそのカオ音エの一人しもしル感じてゐた。「人々の二十五のスを避けにするだつた。
#
# 　　　　　四十九　死
#
# 　絶は色の真悪だつたが、一、一　二十六ン病《
#
# 　彼等は何とも言つた。芒殺すすげてゐた。それは地か木彼は木神の病をを感じた。しかしそれは彼に覚事原稿の中に出した。それは或は或郊聞だつた。彼女の仲違杖りも間もかつてゐるだつた。
#
# 　　　　　三十二十六　彼は或郊かの画家の彼にいちの間とかつかこでち僕びるだつた。
#
# 　　　　　十三
#
# 　それは或は実ら英なち為が後、
# =======================================================================
# 146/146 [==============================] - 1s 6ms/step - loss: 0.0211
#
# Generating text after epoch: 30
# Generating with seed: 「とかつかこでち僕びるだつた。
#
# 　　　　　十三
#
# 　それは或は実ら英なち為が後、」
# ...Diversity: 1.0
# ...Generated:  ゲ前は明らえいやうに憂い匂》を眺め、なかつた。
#
# 　　　　三十六　形
#
# 　彼は絶六母もらずと思つた。が、同エやい人棟《鬼さ》のボオ声を感じてゐた。誰し「新しらず彼の妻は彼等の同じたびは。……
#
# 　　　　　二十六　彼は梯或車の生の上にかう云ふ時に彼等の娘の巻煙当りの智のに足を剥、絶えよまま息来た。
#
# 　　　　　十三　破十歳の彼はいやうランダやう云ふ人等を見渡してゐた社の姉を愛れてゐた。それは彼自身リ五この友だこと話しけだつた。彼女は梯度でも身も同時に恐るだにはゐられなかつた。
#
# 　　　　　四十九　死
#
# 　病殺すは彼等の主るや一人フスイギ人のストルトを恐るくともなかつた。彼はいつの上にかつた。
#
# 　三　五、彼は渡の向うにこちだつた。が、同暗の花をこののを感るどにはかには彼と一層家の歓みよりも己を見出した。しかしそれは彼の小言道を通りかつた。が、ルの画家は彼等だけだつた。彼はあのや熱に彼の心の臭
# =======================================================================
# CPU times: user 8min 3s, sys: 27.7 s, total: 8min 31s
# Wall time: 8min 38s

# %%
from keras.models import load_model

model_path="/content/drive/MyDrive/E資格機械学習プロジェクト/文章生成/output/generator_model_30.h5"

model = load_model(model_path)
